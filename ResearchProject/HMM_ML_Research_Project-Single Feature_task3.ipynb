# %%
import numpy as np
from hmmlearn import hmm
import pandas as pd
import csv
import pathlib
import sys
sys.path.insert(0, '/Users/smaan/ml/FileParser')
import CONSTANTS, util

# %% [markdown]
# I would train 6 HMM models. 3 for experts(who have got task correct) and 3 for novices(who got their task incorrect).
# I am using Gaussian HMM because the value for line_type is continuous in nature.

# %%
paths = [CONSTANTS.path_to_csv_per_user_correctness_training,CONSTANTS.path_to_csv_per_user_correctness_test]

X_train_novices_task2 = np.array([])
len_train_novices_task2 = []
X_test_novices_task2 = np.array([])
len_test_novices_task2 = []
datasets_novices_task2 = [X_train_novices_task2, X_test_novices_task2]
len_datasets_novices_task2 =[len_train_novices_task2, len_test_novices_task2]

X_train_novices_task3 = np.array([])
len_train_novices_task3 = []
X_test_novices_task3 = np.array([])
len_test_novices_task3 = []
datasets_novices_task3 = [X_train_novices_task3, X_test_novices_task3]
len_datasets_novices_task3 =[len_train_novices_task3, len_test_novices_task3]

X_train_novices_task4 = np.array([])
len_train_novices_task4 = []
X_test_novices_task4 = np.array([])
len_test_novices_task4 = []
datasets_novices_task4 = [X_train_novices_task4, X_test_novices_task4]
len_datasets_novices_task4 =[len_train_novices_task4, len_test_novices_task4]


X_train_experts_task2 = np.array([])
len_train_experts_task2 = []
X_test_experts_task2 = np.array([])
len_test_experts_task2 = []
datasets_experts_task2 = [X_train_experts_task2, X_test_experts_task2]
len_datasets_experts_task2 =[len_train_experts_task2, len_test_experts_task2]

X_train_experts_task3 = np.array([])
len_train_experts_task3 = []
X_test_experts_task3 = np.array([])
len_test_experts_task3 = []
datasets_experts_task3 = [X_train_experts_task3, X_test_experts_task3]
len_datasets_experts_task3 =[len_train_experts_task3, len_test_experts_task3]

X_train_experts_task4 = np.array([])
len_train_experts_task4 = []
X_test_experts_task4 = np.array([])
len_test_experts_task4 = []
datasets_experts_task4 = [X_train_experts_task4, X_test_experts_task4]
len_datasets_experts_task4 =[len_train_experts_task4, len_test_experts_task4]

for i in range(len(paths)):
    current_directory = pathlib.Path(paths[i])
    
    for directory in current_directory.glob('**/*'):
        
        try:
            if "Task2" in str(directory) and "Experts" in str(directory) and "new" in str(directory):

                print(("T3 and Experts" + str(directory)))
                df = pd.read_csv(directory)

                X = np.array(df['line_type'])
                print((X.shape))
                print(("before [datasets_experts_task2[i]", len(datasets_experts_task2[i])))
                print((datasets_experts_task2[i]))


                datasets_experts_task2[i]= np.concatenate([datasets_experts_task2[i],X])

                print(("after datasets_experts_task2[i]:", len(datasets_experts_task2[i])))
                if len(X) == 0:
                    continue
                len_datasets_experts_task2[i].append(len(X))
                
            elif "Task3" in str(directory) and "Experts" in str(directory) and "new" in str(directory):
                print(("T3 and Experts" +  str(directory)))
                df = pd.read_csv(directory)
                X = np.array(df['line_type'])
                print((X.shape))
                print(("before [datasets_experts_task3[i]",  len(datasets_experts_task3[i])))
                datasets_experts_task3[i]= np.concatenate([datasets_experts_task3[i],X])
                
                print(("after datasets_experts_task3[i]:", len(datasets_experts_task3[i])))
                if len(X) == 0:
                    continue
                len_datasets_experts_task3[i].append(len(X))
                
            elif "Task4" in str(directory) and "Experts" in str(directory) and "new" in str(directory):
                print(("T4 and Experts" + str(directory)))
                df = pd.read_csv(directory)
                X = np.array(df['line_type'])
                print((X.shape))
                print(("before [datasets_experts_task4[i]", len(datasets_experts_task4[i])))
                datasets_experts_task4[i]= np.concatenate([datasets_experts_task4[i],X])
                
                print(("after datasets_experts_task4[i]:", len(datasets_experts_task4[i])))
                if len(X) == 0:
                    continue
                len_datasets_experts_task4[i].append(len(X))
                
            elif "Task2" in str(directory) and "Novices" in str(directory) and "new" in str(directory):
                print(("T3 and Novices" + str(directory)))
                df = pd.read_csv(directory)
                X = np.array(df['line_type'])
                print((X.shape))
                print(("before [datasets_novices_task2[i]", len(datasets_novices_task2[i])))
                datasets_novices_task2[i] = np.concatenate([datasets_novices_task2[i],X])
                
                print(("after datasets_novices_task2[i]:", len(datasets_novices_task2[i])))
                if len(X) == 0:
                    continue
                len_datasets_novices_task2[i].append(len(X))
                            
                
            elif "Task3" in str(directory) and "Novices" in str(directory) and "new" in str(directory):
                print(("T3 and Novices" + str(directory)))
                df = pd.read_csv(directory)
                X = np.array(df['line_type'])
                print((X.shape))
                print(("before [datasets_novices_task3[i]", len(datasets_novices_task3[i])))
                datasets_novices_task3[i] = np.concatenate([datasets_novices_task3[i],X])
                
                print(("after datasets_novices_task3[i]:", len(datasets_novices_task3[i])))
                if len(X) == 0:
                    continue
                len_datasets_novices_task3[i].append(len(X))
                
            elif "Task4" in str(directory) and "Novices" in str(directory) and "new" in str(directory):
                print(("T4 and Novices" + str(directory)))
                df = pd.read_csv(directory)
                X = np.array(df['line_type'])
                print((X.shape))
                print(("before [datasets_novices_task4[i]",  len(datasets_novices_task4[i])))
                datasets_novices_task4[i] = np.concatenate([datasets_novices_task4[i],X])
                
                print(("after datasets_novices_task4[i]:",  len(datasets_novices_task4[i])))
                if len(X) == 0:
                    continue
                len_datasets_novices_task4[i].append(len(X))
            
        except Exception as e:
            print(e)
            print(("Error!", directory))
# Out:
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U30T3_new.csv
# (21969,)
# ('before [datasets_novices_task3[i]', 0)
# ('after datasets_novices_task3[i]:', 21969)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U24T3_new.csv
# (18857,)
# ('before [datasets_novices_task3[i]', 21969)
# ('after datasets_novices_task3[i]:', 40826)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U11T3_new.csv
# (23303,)
# ('before [datasets_novices_task3[i]', 40826)
# ('after datasets_novices_task3[i]:', 64129)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U29T3_new.csv
# (20278,)
# ('before [datasets_novices_task3[i]', 64129)
# ('after datasets_novices_task3[i]:', 84407)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U7T3_new.csv
# (17326,)
# ('before [datasets_novices_task3[i]', 84407)
# ('after datasets_novices_task3[i]:', 101733)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U22T3_new.csv
# (15495,)
# ('before [datasets_novices_task3[i]', 101733)
# ('after datasets_novices_task3[i]:', 117228)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U28T3_new.csv
# (22456,)
# ('before [datasets_novices_task3[i]', 117228)
# ('after datasets_novices_task3[i]:', 139684)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U23T3_new.csv
# (19533,)
# ('before [datasets_novices_task3[i]', 139684)
# ('after datasets_novices_task3[i]:', 159217)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U3T3_new.csv
# (15156,)
# ('before [datasets_novices_task3[i]', 159217)
# ('after datasets_novices_task3[i]:', 174373)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U13T3_new.csv
# (23102,)
# ('before [datasets_novices_task3[i]', 174373)
# ('after datasets_novices_task3[i]:', 197475)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U5T3_new.csv
# (18278,)
# ('before [datasets_novices_task3[i]', 197475)
# ('after datasets_novices_task3[i]:', 215753)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U8T3_new.csv
# (22267,)
# ('before [datasets_novices_task3[i]', 215753)
# ('after datasets_novices_task3[i]:', 238020)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Experts/U25T3_new.csv
# (27264,)
# ('before [datasets_experts_task3[i]', 0)
# ('after datasets_experts_task3[i]:', 27264)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Experts/U31T3_new.csv
# (33450,)
# ('before [datasets_experts_task3[i]', 27264)
# ('after datasets_experts_task3[i]:', 60714)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Experts/U26T3_new.csv
# (26026,)
# ('before [datasets_experts_task3[i]', 60714)
# ('after datasets_experts_task3[i]:', 86740)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Experts/U27T3_new.csv
# (29815,)
# ('before [datasets_experts_task3[i]', 86740)
# ('after datasets_experts_task3[i]:', 116555)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Experts/U9T3_new.csv
# (32066,)
# ('before [datasets_experts_task3[i]', 116555)
# ('after datasets_experts_task3[i]:', 148621)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Novices/U13T4_new.csv
# (39190,)
# ('before [datasets_novices_task4[i]', 0)
# ('after datasets_novices_task4[i]:', 39190)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Novices/U5T4_new.csv
# (36917,)
# ('before [datasets_novices_task4[i]', 39190)
# ('after datasets_novices_task4[i]:', 76107)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Novices/U29T4_new.csv
# (38199,)
# ('before [datasets_novices_task4[i]', 76107)
# ('after datasets_novices_task4[i]:', 114306)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Novices/U11T4_new.csv
# (41125,)
# ('before [datasets_novices_task4[i]', 114306)
# ('after datasets_novices_task4[i]:', 155431)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Novices/U24T4_new.csv
# (34123,)
# ('before [datasets_novices_task4[i]', 155431)
# ('after datasets_novices_task4[i]:', 189554)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Novices/U28T4_new.csv
# (43844,)
# ('before [datasets_novices_task4[i]', 189554)
# ('after datasets_novices_task4[i]:', 233398)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Novices/U31T4_new.csv
# (42989,)
# ('before [datasets_novices_task4[i]', 233398)
# ('after datasets_novices_task4[i]:', 276387)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Novices/U23T4_new.csv
# (37716,)
# ('before [datasets_novices_task4[i]', 276387)
# ('after datasets_novices_task4[i]:', 314103)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Experts/U26T4_new.csv
# (45936,)
# ('before [datasets_experts_task4[i]', 0)
# ('after datasets_experts_task4[i]:', 45936)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Experts/U8T4_new.csv
# (52618,)
# ('before [datasets_experts_task4[i]', 45936)
# ('after datasets_experts_task4[i]:', 98554)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Experts/U27T4_new.csv
# (51268,)
# ('before [datasets_experts_task4[i]', 98554)
# ('after datasets_experts_task4[i]:', 149822)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Experts/U9T4_new.csv
# (55739,)
# ('before [datasets_experts_task4[i]', 149822)
# ('after datasets_experts_task4[i]:', 205561)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Experts/U30T4_new.csv
# (53833,)
# ('before [datasets_experts_task4[i]', 205561)
# ('after datasets_experts_task4[i]:', 259394)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Experts/U22T4_new.csv
# (46532,)
# ('before [datasets_experts_task4[i]', 259394)
# ('after datasets_experts_task4[i]:', 305926)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Experts/U7T4_new.csv
# (44900,)
# ('before [datasets_experts_task4[i]', 305926)
# ('after datasets_experts_task4[i]:', 350826)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Experts/U25T4_new.csv
# (46916,)
# ('before [datasets_experts_task4[i]', 350826)
# ('after datasets_experts_task4[i]:', 397742)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Experts/U6T4_new.csv
# (49858,)
# ('before [datasets_experts_task4[i]', 397742)
# ('after datasets_experts_task4[i]:', 447600)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U7T2_new.csv
# (60102,)
# ('before [datasets_novices_task2[i]', 0)
# ('after datasets_novices_task2[i]:', 60102)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U22T2_new.csv
# (57584,)
# ('before [datasets_novices_task2[i]', 60102)
# ('after datasets_novices_task2[i]:', 117686)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U29T2_new.csv
# (66855,)
# ('before [datasets_novices_task2[i]', 117686)
# ('after datasets_novices_task2[i]:', 184541)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U30T2_new.csv
# (65112,)
# ('before [datasets_novices_task2[i]', 184541)
# ('after datasets_novices_task2[i]:', 249653)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U24T2_new.csv
# (62252,)
# ('before [datasets_novices_task2[i]', 249653)
# ('after datasets_novices_task2[i]:', 311905)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U11T2_new.csv
# (70262,)
# ('before [datasets_novices_task2[i]', 311905)
# ('after datasets_novices_task2[i]:', 382167)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U23T2_new.csv
# (62322,)
# ('before [datasets_novices_task2[i]', 382167)
# ('after datasets_novices_task2[i]:', 444489)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U28T2_new.csv
# (69513,)
# ('before [datasets_novices_task2[i]', 444489)
# ('after datasets_novices_task2[i]:', 514002)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U10T2_new.csv
# (69124,)
# ('before [datasets_novices_task2[i]', 514002)
# ('after datasets_novices_task2[i]:', 583126)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U8T2_new.csv
# (63768,)
# ('before [datasets_novices_task2[i]', 583126)
# ('after datasets_novices_task2[i]:', 646894)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U13T2_new.csv
# (69513,)
# ('before [datasets_novices_task2[i]', 646894)
# ('after datasets_novices_task2[i]:', 716407)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U26T2_new.csv
# (61945,)
# ('before [datasets_novices_task2[i]', 716407)
# ('after datasets_novices_task2[i]:', 778352)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Experts/U6T2_new.csv
# (78280,)
# ('before [datasets_experts_task2[i]', 0)
# []
# ('after datasets_experts_task2[i]:', 78280)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Experts/U25T2_new.csv
# (75609,)
# ('before [datasets_experts_task2[i]', 78280)
# [6. 7. 7. ... 0. 0. 6.]
# ('after datasets_experts_task2[i]:', 153889)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Experts/U31T2_new.csv
# (81123,)
# ('before [datasets_experts_task2[i]', 153889)
# [ 6.  7.  7. ... 11. 11. 11.]
# ('after datasets_experts_task2[i]:', 235012)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Experts/U5T2_new.csv
# (74668,)
# ('before [datasets_experts_task2[i]', 235012)
# [6. 7. 7. ... 0. 2. 1.]
# ('after datasets_experts_task2[i]:', 309680)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Experts/U9T2_new.csv
# (82666,)
# ('before [datasets_experts_task2[i]', 309680)
# [ 6.  7.  7. ...  9.  0. 11.]
# ('after datasets_experts_task2[i]:', 392346)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Experts/U27T2_new.csv
# (79610,)
# ('before [datasets_experts_task2[i]', 392346)
# [6. 7. 7. ... 1. 6. 0.]
# ('after datasets_experts_task2[i]:', 471956)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task3/Novices/U1T3_new.csv
# (713,)
# ('before [datasets_novices_task3[i]', 0)
# ('after datasets_novices_task3[i]:', 713)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task3/Novices/U2T3_new.csv
# (2977,)
# ('before [datasets_novices_task3[i]', 713)
# ('after datasets_novices_task3[i]:', 3690)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task3/Experts/U6T3_new.csv
# (5865,)
# ('before [datasets_experts_task3[i]', 0)
# ('after datasets_experts_task3[i]:', 5865)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task3/Experts/U4T3_new.csv
# (3157,)
# ('before [datasets_experts_task3[i]', 5865)
# ('after datasets_experts_task3[i]:', 9022)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task4/Novices/U3T4_new.csv
# (7015,)
# ('before [datasets_novices_task4[i]', 0)
# ('after datasets_novices_task4[i]:', 7015)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task4/Novices/U2T4_new.csv
# (8179,)
# ('before [datasets_novices_task4[i]', 7015)
# ('after datasets_novices_task4[i]:', 15194)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task4/Experts/U4T4_new.csv
# (10491,)
# ('before [datasets_experts_task4[i]', 0)
# ('after datasets_experts_task4[i]:', 10491)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task4/Experts/U1T4_new.csv
# (9331,)
# ('before [datasets_experts_task4[i]', 10491)
# ('after datasets_experts_task4[i]:', 19822)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task2/Novices/U1T2_new.csv
# (12185,)
# ('before [datasets_novices_task2[i]', 0)
# ('after datasets_novices_task2[i]:', 12185)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task2/Novices/U2T2_new.csv
# (12901,)
# ('before [datasets_novices_task2[i]', 12185)
# ('after datasets_novices_task2[i]:', 25086)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task2/Experts/U3T2_new.csv
# (14160,)
# ('before [datasets_experts_task2[i]', 0)
# []
# ('after datasets_experts_task2[i]:', 14160)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task2/Experts/U4T2_new.csv
# (15143,)
# ('before [datasets_experts_task2[i]', 14160)
# [ 6.  7.  7. ... 11.  6.  6.]
# ('after datasets_experts_task2[i]:', 29303)

# %% [markdown]
# # Train a HMM for Experts at Task 2

# %%
# Train a HMM for the Experts in Task 2

states = ["Expert", "Novice"]
n_states = len(states)

df_U9T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task3/Experts/U9T3_new.csv')
df_U25T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task3/Experts/U25T3_new.csv')
df_U26T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task3/Experts/U26T3_new.csv')
df_U27T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task3/Experts/U27T3_new.csv')
df_U31T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task3/Experts/U31T3_new.csv')


X_train_U9T3 = np.array((df_U9T3['line_type']))
X_train_U25T3 = np.array((df_U25T3['line_type']))
X_train_U26T3 = np.array((df_U26T3['line_type']))
X_train_U27T3 = np.array((df_U27T3['line_type']))
X_train_U31T3 = np.array((df_U31T3['line_type']))


X_train_expert = np.concatenate([X_train_U9T3, X_train_U25T3,X_train_U26T3,X_train_U27T3,X_train_U31T3]).T
lengths = [len(X_train_U9T3), len(X_train_U25T3), len(X_train_U26T3), len(X_train_U27T3), len(X_train_U31T3)]

# Learning model parameters: transmission & emission matrices

    
model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
model_train_experts_task2.fit(X_train_expert.reshape(-1,1), lengths)
    
    
print("Expert HMM: Transition Probabilities: ")
print(model_train_experts_task2.transmat_)

print("Expert HMM start prob:", model_train_experts_task2.startprob_)
# Out:
# Expert HMM: Transition Probabilities:
# [[0.78625549 0.21374451]
#  [0.27952981 0.72047019]]
# Expert HMM start prob: [1.00000000e+000 3.44599113e-175]

# %% [markdown]
# # Train a HMM for Novices at Task 2

# %%
states = ["Expert", "Novice"]
n_states = len(states)

df_U5T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task3/Novices/U5T3_new.csv')
df_U8T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task3/Novices/U8T3_new.csv')
df_U11T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task3/Novices/U11T3_new.csv')
df_U13T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task3/Novices/U13T3_new.csv')
df_U22T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task3/Novices/U22T3_new.csv')


X_train_U5T3 = np.array((df_U5T3['line_type']))
X_train_U8T3 = np.array((df_U8T3['line_type']))
X_train_U11T3 = np.array((df_U11T3['line_type']))
X_train_U13T3 = np.array((df_U13T3['line_type']))
X_train_U22T3 = np.array((df_U22T3['line_type']))

X_train_novices = np.concatenate([X_train_U5T3,X_train_U8T3 , X_train_U11T3, X_train_U11T3, X_train_U22T3]).T
lengths_novices = [len(X_train_U5T3), len(X_train_U8T3), len(X_train_U11T3), len(X_train_U11T3), len(X_train_U22T3)]

# Learning model parameters: transmission & emission matrices


model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
model_train_novices_task2.fit(X_train_novices.reshape(-1,1), lengths_novices)
    
    
print("Novice HMM: Transition Probabilities: ")
print(model_train_novices_task2.transmat_)
print("Novice start prob:", model_train_novices_task2.startprob_)
# Out:
# Novice HMM: Transition Probabilities:
# [[0.73293654 0.26706346]
#  [0.20120703 0.79879297]]
# Novice start prob: [1.8311074e-167 1.0000000e+000]

# %% [markdown]
# # Evaluation of Expert Participant on both the HMMs

# %%
print("\n--------------------------------- Model: Expert -----------------------------------")
print("Testing with Expert User")
model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


# Rainy
model_test_expert.startprob_ = model_train_experts_task2.startprob_

model_test_expert.transprob_ = np.array([
  [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
  [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
])



df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
# Estimate model parameters.
model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1,1))


# Find most likely state (hidden) sequence corresponding to the observation sequence
# We use the following function "decode": the first argument should be the observation sequence (matrix)
logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U4T3_new.reshape(-1,1), algorithm="viterbi")




print("\nProbability of Expert at Task 2:")
print(logprob_expert_task2)


print("\n--------------------------------- Model: Novice -----------------------------------")



model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


# Rainy
model_test_novice.startprob_ = model_train_novices_task2.startprob_

model_test_novice.transprob_ = np.array([
  [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
  [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
])



# df_U22T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U22T3.csv')
# X_test_U2T3 = np.array([df_U22T3['token_type']]).T
# Estimate model parameters.
model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1,1))


# Find most likely state (hidden) sequence corresponding to the observation sequence
# We use the following function "decode": the first argument should be the observation sequence (matrix)
logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U4T3_new.reshape(-1,1), algorithm="viterbi")




print("\nProbability of Novice at Task 2:")
print(logprob_novice_task2)


if logprob_expert_task2 > logprob_novice_task2:
    print("Participant is an Expert")
    
else:
    print("Participant is an Novice")
# Out:
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
#
# Probability of Expert at Task 2:
# -7268.481185264006
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7293.652893823398
# Participant is an Expert

# %%
print("\n--------------------------------- Model: Expert -----------------------------------")
print("Testing with Novice User")
model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


# Rainy
model_test_expert.startprob_ = model_train_experts_task2.startprob_

model_test_expert.transprob_ = np.array([
  [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
  [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
])



df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')

X_test_U2T3 = np.array((df_U2T3['line_type']))
# Estimate model parameters.
model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


# Find most likely state (hidden) sequence corresponding to the observation sequence
# We use the following function "decode": the first argument should be the observation sequence (matrix)
logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




print("\nProbability of Expert at Task 2:")
print(logprob_expert_task2)


print("\n--------------------------------- Model: Novice -----------------------------------")



model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


# Rainy
model_test_novice.startprob_ = model_train_novices_task2.startprob_

model_test_novice.transprob_ = np.array([
  [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
  [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
])




# Estimate model parameters.
model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


# Find most likely state (hidden) sequence corresponding to the observation sequence
# We use the following function "decode": the first argument should be the observation sequence (matrix)
logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




print("\nProbability of Novice at Task 2:")
print(logprob_novice_task2)


if logprob_expert_task2 > logprob_novice_task2:
    print("Participant is an Expert")
    
else:
    print("Participant is a Novice")
# Out:
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216927000174
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000643
# Participant is an Expert

# %% [markdown]
# # Adding all users for Experts and Task 2

# %%
# Train a HMM for the Experts in Task 2

states = ["Expert", "Novice"]
n_states = len(states)

X_train_experts_task2 = np.array(datasets_experts_task2[0])

print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])


# Learning model parameters: transmission & emission matrices

    
model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), len_datasets_experts_task2[0])
    
    
print("Expert HMM: Transition Probabilities: ")
print(model_train_experts_task2.transmat_)

print("Expert HMM start prob:", model_train_experts_task2.startprob_)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# Expert HMM: Transition Probabilities:
# [[0.77574281 0.22425719]
#  [0.23153541 0.76846459]]
# Expert HMM start prob: [1.00000000e+000 4.70919098e-208]

# %% [markdown]
# # Adding all users for Novices and Task 2

# %%
states = ["Expert", "Novice"]
n_states = len(states)

X_train_novices_task2 = np.array(datasets_novices_task2[0])

print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

# Learning model parameters: transmission & emission matrices

    
model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), len_datasets_novices_task2[0])
    
    
print("Novice HMM: Transition Probabilities: ")
print(model_train_novices_task2.transmat_)
print("Novice start prob:", model_train_novices_task2.startprob_)
# Out:
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# Novice HMM: Transition Probabilities:
# [[0.7542495  0.2457505 ]
#  [0.21990018 0.78009982]]
# Novice start prob: [1.56351085e-206 1.00000000e+000]

# %% [markdown]
# # Evaluation for experts at task 2

# %%
print("\n--------------------------------- Model: Expert -----------------------------------")
print("Testing with Expert User")
model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


# Rainy
model_test_expert.startprob_ = model_train_experts_task2.startprob_

model_test_expert.transprob_ = np.array([
  [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
  [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
])



df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

# Estimate model parameters.
model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1,1))


# Find most likely state (hidden) sequence corresponding to the observation sequence
# We use the following function "decode": the first argument should be the observation sequence (matrix)
logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U4T3_new.reshape(-1,1), algorithm="viterbi")




print("\nProbability of Expert at Task 2:")
print(logprob_expert_task2)


print("\n--------------------------------- Model: Novice -----------------------------------")



model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


# Rainy
model_test_novice.startprob_ = model_train_novices_task2.startprob_

model_test_novice.transprob_ = np.array([
  [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
  [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
])



df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
X_test_U2T3 = np.array((df_U2T3['line_type'], df_U2T3['token_type'])).T
# Estimate model parameters.
model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1,1))


# Find most likely state (hidden) sequence corresponding to the observation sequence
# We use the following function "decode": the first argument should be the observation sequence (matrix)
logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U4T3_new.reshape(-1,1), algorithm="viterbi")




print("\nProbability of Novice at Task 2:")
print(logprob_novice_task2)


if logprob_expert_task2 > logprob_novice_task2:
    print("Participant is an Expert")
    
else:
    print("Participant is an Novice")
# Out:
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.481185264006
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264073
# Participant is an Expert

# %% [markdown]
# # Model evaluation of novice at task 2

# %%
print("\n--------------------------------- Model: Expert -----------------------------------")
print("Testing with Novice User")
model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


# Rainy
model_test_expert.startprob_ = model_train_experts_task2.startprob_

model_test_expert.transprob_ = np.array([
  [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
  [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
])



df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
X_test_U2T3 = np.array(df_U2T3['line_type'],df_U2T3['token_type'] ).T
# Estimate model parameters.
model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


# Find most likely state (hidden) sequence corresponding to the observation sequence
# We use the following function "decode": the first argument should be the observation sequence (matrix)
logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




print("\nProbability of Expert at Task 2:")
print(logprob_expert_task2)


print("\n--------------------------------- Model: Novice -----------------------------------")



model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


# Rainy
model_test_novice.startprob_ = model_train_novices_task2.startprob_

model_test_novice.transprob_ = np.array([
  [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
  [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
])




# Estimate model parameters.
model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


# Find most likely state (hidden) sequence corresponding to the observation sequence
# We use the following function "decode": the first argument should be the observation sequence (matrix)
logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




print("\nProbability of Novice at Task 2:")
print(logprob_novice_task2)


if logprob_expert_task2 > logprob_novice_task2:
    print("Participant is an Expert")
    
else:
    print("Participant is a Novice")
# Out:
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216927000174
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000643
# Participant is an Expert

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 100 else 100
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:100] if len(data) > 100 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-100:] if len(data) > 100 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 600
# length of each dataset experts [100, 100, 100, 100, 100, 100]

# %% [markdown]
# # Creating dataset for novice users

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 100 else 100
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:100] if len(data) > 100 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-100:] if len(data) > 100 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 1200
# length of each dataset novices [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100]

# %% [markdown]
# # Evaluation by increasing the users for first 100 sequences of line_type

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U1T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U1T3_new.csv')
    X_test_U1T3_new = np.array((df_U1T3_new['line_type']))
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U1T3_new.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U1T3_new.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U1T3_new.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U1T3_new.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (300,) : [100, 100, 100]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.7943812  0.2056188 ]
#  [0.02589727 0.97410273]]
# Expert HMM start prob for 2 users:  [7.95173826e-40 1.00000000e+00]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.7943812  0.2056188 ]
#  [0.02589727 0.97410273]]
# Novice start prob for 2 users:  [7.95173826e-40 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7271.846725540856
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7271.846725540856
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -1668.1981244194467
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -1656.235947626911
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (400,) : [100, 100, 100, 100]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.97410267 0.02589733]
#  [0.20561949 0.79438051]]
# Expert HMM start prob for 3 users:  [1.00000000e+00 1.06979181e-39]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.79438051 0.20561949]
#  [0.02589733 0.97410267]]
# Novice start prob for 3 users:  [1.06979181e-39 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7271.506711131182
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7271.50671113118
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -1656.235947626911
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -1691.1086735629556
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (500,) : [100, 100, 100, 100, 100]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.7943801  0.2056199 ]
#  [0.02589737 0.97410263]]
# Expert HMM start prob for 4 users:  [1.27880486e-39 1.00000000e+00]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.7943801  0.2056199 ]
#  [0.02589737 0.97410263]]
# Novice start prob for 4 users:  [1.27880486e-39 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7271.299785457586
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264073
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -1656.235947626911
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -1656.235947626911
# Participant is a Novice for 4 users:
# ---------------------------------------------------------------------------
# (600,) : [100, 100, 100, 100, 100, 100]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.79437983 0.20562017]
#  [0.02589739 0.97410261]]
# Expert HMM start prob for 5 users:  [1.44065085e-39 1.00000000e+00]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.79437983 0.20562017]
#  [0.02589739 0.97410261]]
# Novice start prob for 5 users:  [1.44065085e-39 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7271.160938172423
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7271.160938172423
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -1656.235947626911
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -1690.811042630718
# Participant is an Expert for 5 users:

# %% [markdown]
# # Evaluation by increasing users for last 100 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U1T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U1T3_new.csv')
    X_test_U1T3_new = np.array((df_U1T3_new['line_type']))
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U1T3_new.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U1T3_new.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U1T3_new.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U1T3_new.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (300,) : [100, 100, 100]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.83818369 0.16181631]
#  [0.18126208 0.81873792]]
# Expert HMM start prob for 2 users:  [0.38353439 0.61646561]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.88044714 0.11955286]
#  [0.34272527 0.65727473]]
# Novice start prob for 2 users:  [0.66053709 0.33946291]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.474559418644
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.478623211194
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -1656.3079832180129
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -1656.2644390687929
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (400,) : [100, 100, 100, 100]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.74476385 0.25523615]
#  [0.26947457 0.73052543]]
# Expert HMM start prob for 3 users:  [0.289777 0.710223]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.86477876 0.13522124]
#  [0.21420485 0.78579515]]
# Novice start prob for 3 users:  [0.49778235 0.50221765]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.479107399587
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.4766649868
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -1656.259128836009
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -1656.286338126131
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (500,) : [100, 100, 100, 100, 100]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.73089423 0.26910577]
#  [0.174917   0.825083  ]]
# Expert HMM start prob for 4 users:  [0.75925256 0.24074744]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.87118218 0.12881782]
#  [0.1680958  0.8319042 ]]
# Novice start prob for 4 users:  [0.39983339 0.60016661]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.470599868692
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.474894808928
# Participant is an Expert for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -1656.2543592745255
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -1656.30444586277
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (600,) : [100, 100, 100, 100, 100, 100]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.70797822 0.29202178]
#  [0.17453288 0.82546712]]
# Expert HMM start prob for 5 users:  [0.60796982 0.39203018]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.83604085 0.16395915]
#  [0.18374707 0.81625293]]
# Novice start prob for 5 users:  [0.33127794 0.66872206]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.478051622675
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.478706473413
# Participant is an Expert for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -1656.306117396913
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -1656.263528128835
# Participant is a Novice for 5 users:

# %% [markdown]
# # generate dataset for sequence 200

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 200 else 200
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:200] if len(data) > 200 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-200:] if len(data) > 200 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)


# creating the dataset of the first 100 sequences task 2 novice users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 200 else 200
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:200] if len(data) > 200 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-200:] if len(data) > 200 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 1200
# length of each dataset experts [200, 200, 200, 200, 200, 200]
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 2400
# length of each dataset novices [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]

# %% [markdown]
# # Evaluation by increasing the sequences first 200 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
    X_test_U2T3 = np.array((df_U2T3['line_type']))
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (600,) : [200, 200, 200]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.93919058 0.06080942]
#  [0.28923147 0.71076853]]
# Expert HMM start prob for 2 users:  [1.00000000e+00 1.56994347e-30]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.93919058 0.06080942]
#  [0.28923147 0.71076853]]
# Novice start prob for 2 users:  [1.00000000e+00 1.56994347e-30]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.152009554283
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264006
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216927000174
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.6384820137555
# Participant is an Expert for 2 users:
# ---------------------------------------------------------------------------
# (800,) : [200, 200, 200, 200]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.93919014 0.06080986]
#  [0.28923287 0.71076713]]
# Expert HMM start prob for 3 users:  [1.00000000e+00 1.67847337e-30]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.71076713 0.28923287]
#  [0.06080986 0.93919014]]
# Novice start prob for 3 users:  [1.67847337e-30 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.481185264006
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264073
# Participant is an Expert for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.638466732103
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.638466732095
# Participant is a Novice for 3 users:
# ---------------------------------------------------------------------------
# (1000,) : [200, 200, 200, 200, 200]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.93918987 0.06081013]
#  [0.28923372 0.71076628]]
# Expert HMM start prob for 4 users:  [1.00000000e+00 1.74761667e-30]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.71076628 0.28923372]
#  [0.06081013 0.93918987]]
# Novice start prob for 4 users:  [1.74761667e-30 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.150210182617
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.150210182636
# Participant is an Expert for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.6384570580985
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.638457058103
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (1200,) : [200, 200, 200, 200, 200, 200]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.71076571 0.28923429]
#  [0.06081031 0.93918969]]
# Expert HMM start prob for 5 users:  [1.79548459e-30 1.00000000e+00]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.93918969 0.06081031]
#  [0.28923429 0.71076571]]
# Novice start prob for 5 users:  [1.00000000e+00 1.79548459e-30]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.149735665988
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264006
# Participant is an Expert for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216927000643
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.638450385737
# Participant is an Expert for 5 users:

# %% [markdown]
# # Evaluation by increasing users last 200

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
    X_test_U2T3 = np.array(df_U2T3['line_type'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (600,) : [200, 200, 200]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.78063014 0.21936986]
#  [0.24073735 0.75926265]]
# Expert HMM start prob for 2 users:  [0.64802042 0.35197958]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.84407997 0.15592003]
#  [0.3931122  0.6068878 ]]
# Novice start prob for 2 users:  [0.23114733 0.76885267]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.4784930302985
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.47961975092
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.215574192992
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.211448014016
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (800,) : [200, 200, 200, 200]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.74034198 0.25965802]
#  [0.28944136 0.71055864]]
# Expert HMM start prob for 3 users:  [0.46046761 0.53953239]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.82307729 0.17692271]
#  [0.2199134  0.7800866 ]]
# Novice start prob for 3 users:  [0.11816212 0.88183788]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.47600509712
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.464111147943
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.214326797336
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.208411029469
# Participant is a Novice for 3 users:
# ---------------------------------------------------------------------------
# (1000,) : [200, 200, 200, 200, 200]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.73709061 0.26290939]
#  [0.20329303 0.79670697]]
# Expert HMM start prob for 4 users:  [0.37091142 0.62908858]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.82381238 0.17618762]
#  [0.18014317 0.81985683]]
# Novice start prob for 4 users:  [0.8460759 0.1539241]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.47428720252
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.480213540844
# Participant is an Expert for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.21346720328
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216438389471
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (1200,) : [200, 200, 200, 200, 200, 200]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.71969621 0.28030379]
#  [0.18615243 0.81384757]]
# Expert HMM start prob for 5 users:  [0.30666689 0.69333311]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.82460476 0.17539524]
#  [0.20207611 0.79792389]]
# Novice start prob for 5 users:  [0.90156011 0.09843989]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.472700692359
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.4805926458885
# Participant is an Expert for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.212674718637
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216628970705
# Participant is an Expert for 5 users:

# %% [markdown]
# # Generate dataset for 300 sequence

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 300 else 300
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:300] if len(data) > 300 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-300:] if len(data) > 300 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)


# creating the dataset of the first 100 sequences task 2 novice users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 300 else 300
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:300] if len(data) > 300 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-300:] if len(data) > 300 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 1800
# length of each dataset experts [300, 300, 300, 300, 300, 300]
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 3600
# length of each dataset novices [300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300]

# %% [markdown]
# # #valuation for first 300 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
    X_test_U2T3 = np.array(df_U2T3['line_type'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (900,) : [300, 300, 300]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.67059529 0.32940471]
#  [0.06521869 0.93478131]]
# Expert HMM start prob for 2 users:  [7.81335144e-30 1.00000000e+00]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.67059529 0.32940471]
#  [0.06521869 0.93478131]]
# Novice start prob for 2 users:  [7.81335144e-30 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.112382191236
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264073
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.637646674315
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.637646674315
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (1200,) : [300, 300, 300, 300]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.67108078 0.32891922]
#  [0.06504924 0.93495076]]
# Expert HMM start prob for 3 users:  [8.42514307e-36 1.00000000e+00]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.93495076 0.06504924]
#  [0.32891922 0.67108078]]
# Novice start prob for 3 users:  [1.00000000e+00 8.42514307e-36]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.172502077292
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264006
# Participant is an Expert for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6870.344527962908
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000174
# Participant is a Novice for 3 users:
# ---------------------------------------------------------------------------
# (1500,) : [300, 300, 300, 300, 300]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.67107777 0.32892223]
#  [0.06505027 0.93494973]]
# Expert HMM start prob for 4 users:  [9.50571135e-36 1.00000000e+00]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.67107777 0.32892223]
#  [0.06505027 0.93494973]]
# Novice start prob for 4 users:  [9.50571135e-36 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.481185264073
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.172329677738
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6870.214841129801
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6870.214841129801
# Participant is a Novice for 4 users:
# ---------------------------------------------------------------------------
# (1800,) : [300, 300, 300, 300, 300, 300]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.67107568 0.32892432]
#  [0.06505098 0.93494902]]
# Expert HMM start prob for 5 users:  [1.03170255e-35 1.00000000e+00]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.93494902 0.06505098]
#  [0.32892432 0.67107568]]
# Novice start prob for 5 users:  [1.00000000e+00 1.03170255e-35]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.481185264073
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.172223963134
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6870.129943536494
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000174
# Participant is a Novice for 5 users:

# %% [markdown]
# # Evaluation for last 300 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
    X_test_U2T3 = np.array(df_U2T3['line_type'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (900,) : [300, 300, 300]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.7818012  0.2181988 ]
#  [0.19133574 0.80866426]]
# Expert HMM start prob for 2 users:  [0.25984987 0.74015013]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.84627052 0.15372948]
#  [0.34961687 0.65038313]]
# Novice start prob for 2 users:  [0.66098505 0.33901495]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.479376267173
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.478627806361
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.211961900584
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.215641844434
# Participant is an Expert for 2 users:
# ---------------------------------------------------------------------------
# (1200,) : [300, 300, 300, 300]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.75355142 0.24644858]
#  [0.2735709  0.7264291 ]]
# Expert HMM start prob for 3 users:  [0.89284774 0.10715226]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.81951354 0.18048646]
#  [0.20434116 0.79565884]]
# Novice start prob for 3 users:  [0.72927075 0.27072925]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.480535466654
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.47928036745
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216600221574
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.215969513401
# Participant is a Novice for 3 users:
# ---------------------------------------------------------------------------
# (1500,) : [300, 300, 300, 300, 300]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.82153153 0.17846847]
#  [0.27424019 0.72575981]]
# Expert HMM start prob for 4 users:  [0.84905842 0.15094158]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.80033771 0.19966229]
#  [0.17523658 0.82476342]]
# Novice start prob for 4 users:  [0.79360829 0.20639171]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.480234857254
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.469226094493
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.2095296389725
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.210944177903
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (1800,) : [300, 300, 300, 300, 300, 300]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.71299271 0.28700729]
#  [0.16270594 0.83729406]]
# Expert HMM start prob for 5 users:  [0.10674409 0.89325591]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.78248246 0.21751754]
#  [0.19130728 0.80869272]]
# Novice start prob for 5 users:  [0.82722901 0.17277099]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.480538163875
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.467613272525
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.207946345726
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.210143488927
# Participant is an Expert for 5 users:

# %% [markdown]
# # Generate dataset for 400 sequences

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 400 else 400
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:400] if len(data) > 400 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-400:] if len(data) > 400 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)


# creating the dataset of the first 100 sequences task 2 novice users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 400 else 400
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:400] if len(data) > 400 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-400:] if len(data) > 400 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 2400
# length of each dataset experts [400, 400, 400, 400, 400, 400]
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 4800
# length of each dataset novices [400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400]

# %% [markdown]
# # Evaluation for first 400 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
    X_test_U2T3 = np.array(df_U2T3['line_type'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (1200,) : [400, 400, 400]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.47463923 0.52536077]
#  [0.26114156 0.73885844]]
# Expert HMM start prob for 2 users:  [3.74210245e-192 1.00000000e+000]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.47463923 0.52536077]
#  [0.26114156 0.73885844]]
# Novice start prob for 2 users:  [3.74210245e-192 1.00000000e+000]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7293.652893823398
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7293.652893823398
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6893.5563871109325
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6893.5563871109325
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (1600,) : [400, 400, 400, 400]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.73885967 0.26114033]
#  [0.52536137 0.47463863]]
# Expert HMM start prob for 3 users:  [1.00000000e+000 3.08849305e-192]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.47463863 0.52536137]
#  [0.26114033 0.73885967]]
# Novice start prob for 3 users:  [3.08849305e-192 1.00000000e+000]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.481185264006
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264073
# Participant is an Expert for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216927000174
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6893.5563871109325
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (2000,) : [400, 400, 400, 400, 400]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.47461636 0.52538364]
#  [0.26100089 0.73899911]]
# Expert HMM start prob for 4 users:  [4.37234541e-215 1.00000000e+000]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.73899911 0.26100089]
#  [0.52538364 0.47461636]]
# Novice start prob for 4 users:  [1.00000000e+000 4.37234542e-215]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.481185264073
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264006
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216927000643
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000174
# Participant is a Novice for 4 users:
# ---------------------------------------------------------------------------
# (2400,) : [400, 400, 400, 400, 400, 400]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.47461615 0.52538385]
#  [0.26100053 0.73899947]]
# Expert HMM start prob for 5 users:  [4.0460851e-215 1.0000000e+000]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.47461615 0.52538385]
#  [0.26100053 0.73899947]]
# Novice start prob for 5 users:  [4.0460851e-215 1.0000000e+000]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7293.652893823398
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7293.652893823398
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6893.5563871109325
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6893.5563871109325
# Participant is a Novice for 5 users:

# %% [markdown]
# # Evaluation for last 400 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
    X_test_U2T3 = np.array(df_U2T3['line_type'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (1200,) : [400, 400, 400]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.76298861 0.23701139]
#  [0.22239711 0.77760289]]
# Expert HMM start prob for 2 users:  [0.3648635 0.6351365]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.67137733 0.32862267]
#  [0.1473717  0.8526283 ]]
# Novice start prob for 2 users:  [0.3345078 0.6654922]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.474152675456
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.473433471451
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.213399953103
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.215664929116
# Participant is an Expert for 2 users:
# ---------------------------------------------------------------------------
# (1600,) : [400, 400, 400, 400]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.75169621 0.24830379]
#  [0.28955076 0.71044924]]
# Expert HMM start prob for 3 users:  [0.7323171 0.2676829]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.78192945 0.21807055]
#  [0.17879507 0.82120493]]
# Novice start prob for 3 users:  [0.50301862 0.49698138]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.479307427718
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.476676933784
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.212091034479
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.214617923863
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (2000,) : [400, 400, 400, 400, 400]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.77135591 0.22864409]
#  [0.25999753 0.74000247]]
# Expert HMM start prob for 4 users:  [0.42205746 0.57794254]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.79827059 0.20172941]
#  [0.19050791 0.80949209]]
# Novice start prob for 4 users:  [0.39887281 0.60112719]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.475325331798
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.474875522815
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.2139864823175
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.215312806583
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (2400,) : [400, 400, 400, 400, 400, 400]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.72425447 0.27574553]
#  [0.20165414 0.79834586]]
# Expert HMM start prob for 5 users:  [0.47367521 0.52632479]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.79104886 0.20895114]
#  [0.20445023 0.79554977]]
# Novice start prob for 5 users:  [0.49186546 0.50813454]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.476222075806
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.476508268517
# Participant is an Expert for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.214435472501
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.214578847096
# Participant is an Expert for 5 users:

# %% [markdown]
# # Generate dataset for 500 sequences

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 500 else 500
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:500] if len(data) > 500 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-500:] if len(data) > 500 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)


# creating the dataset of the first 100 sequences task 2 novice users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 500 else 500
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:500] if len(data) > 500 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-500:] if len(data) > 500 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 3000
# length of each dataset experts [500, 500, 500, 500, 500, 500]
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 6000
# length of each dataset novices [500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500]

# %% [markdown]
# # Evaluation for first 500 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
    X_test_U2T3 = np.array(df_U2T3['line_type'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (1500,) : [500, 500, 500]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.460727  0.539273 ]
#  [0.2944872 0.7055128]]
# Expert HMM start prob for 2 users:  [1.01716631e-185 1.00000000e+000]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.460727  0.539273 ]
#  [0.2944872 0.7055128]]
# Novice start prob for 2 users:  [1.01716631e-185 1.00000000e+000]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7293.652893823398
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7293.652893823398
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6893.5563871109325
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000643
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (2000,) : [500, 500, 500, 500]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.46072658 0.53927342]
#  [0.2944866  0.7055134 ]]
# Expert HMM start prob for 3 users:  [9.33765922e-186 1.00000000e+000]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.7055134  0.2944866 ]
#  [0.53927342 0.46072658]]
# Novice start prob for 3 users:  [1.00000000e+000 9.33765922e-186]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7293.652893823398
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7293.652893823398
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6893.5563871109325
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000174
# Participant is a Novice for 3 users:
# ---------------------------------------------------------------------------
# (2500,) : [500, 500, 500, 500, 500]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.70551375 0.29448625]
#  [0.53927367 0.46072633]]
# Expert HMM start prob for 4 users:  [1.00000000e+000 8.87063315e-186]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.46072633 0.53927367]
#  [0.29448625 0.70551375]]
# Novice start prob for 4 users:  [8.87063315e-186 1.00000000e+000]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.481185264006
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7293.652893823398
# Participant is an Expert for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216927000174
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6893.5563871109325
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (3000,) : [500, 500, 500, 500, 500, 500]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.46068696 0.53931304]
#  [0.29439533 0.70560467]]
# Expert HMM start prob for 5 users:  [8.28661766e-209 1.00000000e+000]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.70560467 0.29439533]
#  [0.53931304 0.46068696]]
# Novice start prob for 5 users:  [1.00000000e+000 8.28661767e-209]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7293.652893823398
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7293.652893823398
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6893.5563871109325
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000174
# Participant is a Novice for 5 users:

# %% [markdown]
# # Evaluation for last 500 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
    X_test_U2T3 = np.array(df_U2T3['line_type'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (1500,) : [500, 500, 500]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.77649428 0.22350572]
#  [0.26561167 0.73438833]]
# Expert HMM start prob for 2 users:  [0.23613053 0.76386947]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.86805088 0.13194912]
#  [0.31259184 0.68740816]]
# Novice start prob for 2 users:  [1.00000000e+00 5.29613754e-21]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.470428494096
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264006
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216119241088
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000174
# Participant is an Expert for 2 users:
# ---------------------------------------------------------------------------
# (2000,) : [500, 500, 500, 500]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.75018107 0.24981893]
#  [0.30757859 0.69242141]]
# Expert HMM start prob for 3 users:  [0.45180993 0.54819007]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.83157922 0.16842078]
#  [0.21895556 0.78104444]]
# Novice start prob for 3 users:  [0.74334321 0.25665679]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.4773122474735
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.479404026375
# Participant is an Expert for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.214981824145
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216031625735
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (2500,) : [500, 500, 500, 500, 500]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.73219108 0.26780892]
#  [0.24919743 0.75080257]]
# Expert HMM start prob for 4 users:  [0.33563414 0.66436586]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.80450968 0.19549032]
#  [0.19644229 0.80355771]]
# Novice start prob for 4 users:  [0.59450758 0.40549242]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.473461557525
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.477894074283
# Participant is an Expert for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.213054611957
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.213827323442
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (3000,) : [500, 500, 500, 500, 500, 500]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.7189072 0.2810928]
#  [0.2195164 0.7804836]]
# Expert HMM start prob for 5 users:  [0.45493107 0.54506893]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.79702802 0.20297198]
#  [0.20996887 0.79003113]]
# Novice start prob for 5 users:  [0.66151419 0.33848581]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.475911717552
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.478633227287
# Participant is an Expert for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.214960963876
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.213089878976
# Participant is a Novice for 5 users:

# %% [markdown]
# # Generate dataset for 600 sequences

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 600 else 600
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:600] if len(data) > 600 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-600:] if len(data) > 600 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)


# creating the dataset of the first 100 sequences task 2 novice users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 600 else 600
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:600] if len(data) > 600 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-600:] if len(data) > 600 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 3600
# length of each dataset experts [600, 600, 600, 600, 600, 600]
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 7200
# length of each dataset novices [600, 600, 600, 600, 600, 600, 600, 600, 600, 600, 600, 600]

# %% [markdown]
# # Evaluation on first 600 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
    X_test_U2T3 = np.array(df_U2T3['line_type'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (1800,) : [600, 600, 600]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.70975655 0.29024345]
#  [0.50497769 0.49502231]]
# Expert HMM start prob for 2 users:  [1.0000000e+000 6.0721224e-177]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.70975655 0.29024345]
#  [0.50497769 0.49502231]]
# Novice start prob for 2 users:  [1.0000000e+000 6.0721224e-177]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7293.652893823398
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264006
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6893.5563871109325
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000174
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (2400,) : [600, 600, 600, 600]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.49502206 0.50497794]
#  [0.29024303 0.70975697]]
# Expert HMM start prob for 3 users:  [5.75421042e-177 1.00000000e+000]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.49502206 0.50497794]
#  [0.29024303 0.70975697]]
# Novice start prob for 3 users:  [5.75421042e-177 1.00000000e+000]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7293.652893823398
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7293.652893823398
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216927000643
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6893.5563871109325
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (3000,) : [600, 600, 600, 600, 600]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.70975722 0.29024278]
#  [0.50497809 0.49502191]]
# Expert HMM start prob for 4 users:  [1.00000000e+000 5.57154659e-177]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.70975722 0.29024278]
#  [0.50497809 0.49502191]]
# Novice start prob for 4 users:  [1.00000000e+000 5.57154659e-177]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7293.652893823398
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264006
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216927000174
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000174
# Participant is a Novice for 4 users:
# ---------------------------------------------------------------------------
# (3600,) : [600, 600, 600, 600, 600, 600]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.49502182 0.50497818]
#  [0.29024261 0.70975739]]
# Expert HMM start prob for 5 users:  [5.45301871e-177 1.00000000e+000]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.49502182 0.50497818]
#  [0.29024261 0.70975739]]
# Novice start prob for 5 users:  [5.45301871e-177 1.00000000e+000]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7293.652893823398
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7293.652893823398
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6893.5563871109325
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6893.5563871109325
# Participant is a Novice for 5 users:

# %% [markdown]
# # Evaluation on last 600 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
    X_test_U2T3 = np.array(df_U2T3['line_type'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (1800,) : [600, 600, 600]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.71565309 0.28434691]
#  [0.25307829 0.74692171]]
# Expert HMM start prob for 2 users:  [0.7386282 0.2613718]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.87685479 0.12314521]
#  [0.31811332 0.68188668]]
# Novice start prob for 2 users:  [0.34656284 0.65343716]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.479362973332
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.473728276586
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.21601100462
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.21318785656
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (2400,) : [600, 600, 600, 600]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.67423401 0.32576599]
#  [0.27841776 0.72158224]]
# Expert HMM start prob for 3 users:  [0.52395456 0.47604544]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.83591712 0.16408288]
#  [0.2356104  0.7643896 ]]
# Novice start prob for 3 users:  [0.50382178 0.49617822]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.476980507085
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.476688887715
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.214454557381
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.214611824385
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (3000,) : [600, 600, 600, 600, 600]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.70236634 0.29763366]
#  [0.26295702 0.73704298]]
# Expert HMM start prob for 4 users:  [0.36808963 0.63191037]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.78823597 0.21176403]
#  [0.19378431 0.80621569]]
# Novice start prob for 4 users:  [0.39134333 0.60865667]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.474224775434
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.47472229012
# Participant is an Expert for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.213435995487
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.213684770468
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (3600,) : [600, 600, 600, 600, 600, 600]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.69726403 0.30273597]
#  [0.23612234 0.76387766]]
# Expert HMM start prob for 5 users:  [0.30352772 0.69647228]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.80258184 0.19741816]
#  [0.222871   0.777129  ]]
# Novice start prob for 5 users:  [0.68252638 0.31747362]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.47261310281
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.47884367818
# Participant is an Expert for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.215817835266
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.215750220228
# Participant is a Novice for 5 users:

# %% [markdown]
# # Generate dataset for 700 sequences

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 700 else 700
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:700] if len(data) > 700 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-700:] if len(data) > 700 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)


# creating the dataset of the first 100 sequences task 2 novice users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 700 else 700
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:700] if len(data) > 700 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-700:] if len(data) > 700 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 4200
# length of each dataset experts [700, 700, 700, 700, 700, 700]
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 8400
# length of each dataset novices [700, 700, 700, 700, 700, 700, 700, 700, 700, 700, 700, 700]

# %% [markdown]
# # Evaluation for first 700 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
    X_test_U2T3 = np.array(df_U2T3['line_type'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (2100,) : [700, 700, 700]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.49677627 0.50322373]
#  [0.25690233 0.74309767]]
# Expert HMM start prob for 2 users:  [7.64270521e-208 1.00000000e+000]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.74309767 0.25690233]
#  [0.50322373 0.49677627]]
# Novice start prob for 2 users:  [1.00000000e+000 7.64270521e-208]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7293.652893823398
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7293.652893823398
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216927000643
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000174
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (2800,) : [700, 700, 700, 700]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.49677611 0.50322389]
#  [0.2569018  0.7430982 ]]
# Expert HMM start prob for 3 users:  [7.27562302e-208 1.00000000e+000]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.7430982  0.2569018 ]
#  [0.50322389 0.49677611]]
# Novice start prob for 3 users:  [1.00000000e+000 7.27562302e-208]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7293.652893823398
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264006
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216927000643
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6893.5563871109325
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (3500,) : [700, 700, 700, 700, 700]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.74309852 0.25690148]
#  [0.50322399 0.49677601]]
# Expert HMM start prob for 4 users:  [1.00000000e+000 7.06390804e-208]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.49677601 0.50322399]
#  [0.25690148 0.74309852]]
# Novice start prob for 4 users:  [7.06390804e-208 1.00000000e+000]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.481185264006
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264073
# Participant is an Expert for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6893.5563871109325
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000643
# Participant is a Novice for 4 users:
# ---------------------------------------------------------------------------
# (4200,) : [700, 700, 700, 700, 700, 700]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.74309873 0.25690127]
#  [0.50322406 0.49677594]]
# Expert HMM start prob for 5 users:  [1.00000000e+000 6.92620519e-208]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.74309873 0.25690127]
#  [0.50322406 0.49677594]]
# Novice start prob for 5 users:  [1.00000000e+000 6.92620519e-208]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7293.652893823398
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7293.652893823398
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216927000174
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000174
# Participant is a Novice for 5 users:

# %% [markdown]
# # Evaluation for last 700 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
    X_test_U2T3 = np.array(df_U2T3['line_type'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (2100,) : [700, 700, 700]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.73634874 0.26365126]
#  [0.27578617 0.72421383]]
# Expert HMM start prob for 2 users:  [0.34239107 0.65760893]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.88466064 0.11533936]
#  [0.32273516 0.67726484]]
# Novice start prob for 2 users:  [0.66172003 0.33827997]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.473627686444
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.4786353345735
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.21313760001
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.21564562497
# Participant is an Expert for 2 users:
# ---------------------------------------------------------------------------
# (2800,) : [700, 700, 700, 700]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.6859491  0.3140509 ]
#  [0.28747751 0.71252249]]
# Expert HMM start prob for 3 users:  [0.48487805 0.51512195]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.8464048  0.1535952 ]
#  [0.22993001 0.77006999]]
# Novice start prob for 3 users:  [0.48598748 0.51401252]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.47640000539
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.47683840205
# Participant is an Expert for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.214524606299
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.214533285608
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (3500,) : [700, 700, 700, 700, 700]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.69293608 0.30706392]
#  [0.2560388  0.7439612 ]]
# Expert HMM start prob for 4 users:  [0.40107852 0.59892148]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.81857341 0.18142659]
#  [0.21345949 0.78654051]]
# Novice start prob for 4 users:  [0.53141915 0.46858085]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.477946269039
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.476139329592
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.213783529895
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.214394025763
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (4200,) : [700, 700, 700, 700, 700, 700]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.76969465 0.23030535]
#  [0.31291374 0.68708626]]
# Expert HMM start prob for 5 users:  [0.49366139 0.50633861]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.8151208  0.1848792 ]
#  [0.22602174 0.77397826]]
# Novice start prob for 5 users:  [0.56500118 0.43499882]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.4765357673805
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.477530932676
# Participant is an Expert for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.214592625768
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.21410542131
# Participant is a Novice for 5 users:

# %% [markdown]
# # Generate dataset for 800 sequences

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 800 else 800
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:800] if len(data) > 800 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-800:] if len(data) > 800 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)


# creating the dataset of the first 100 sequences task 2 novice users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 800 else 800
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:800] if len(data) > 800 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-800:] if len(data) > 800 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 4800
# length of each dataset experts [800, 800, 800, 800, 800, 800]
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 9600
# length of each dataset novices [800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800]

# %% [markdown]
# # Evaluation for first 800 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
    X_test_U2T3 = np.array(df_U2T3['line_type'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (2400,) : [800, 800, 800]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.74155975 0.25844025]
#  [0.46694222 0.53305778]]
# Expert HMM start prob for 2 users:  [1.00000000e+000 2.99354093e-169]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.53305778 0.46694222]
#  [0.25844025 0.74155975]]
# Novice start prob for 2 users:  [2.99354093e-169 1.00000000e+000]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7293.652893823398
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7293.652893823398
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6893.5563871109325
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6893.5563871109325
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (3200,) : [800, 800, 800, 800]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.74165543 0.25834457]
#  [0.46702213 0.53297787]]
# Expert HMM start prob for 3 users:  [1.00000000e+000 7.99823763e-188]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.53297787 0.46702213]
#  [0.25834457 0.74165543]]
# Novice start prob for 3 users:  [7.99823763e-188 1.00000000e+000]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.481185264006
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7293.652893823398
# Participant is an Expert for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216927000174
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000643
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (4000,) : [800, 800, 800, 800, 800]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.74165561 0.25834439]
#  [0.46702241 0.53297759]]
# Expert HMM start prob for 4 users:  [1.00000000e+000 7.84452785e-188]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.74165561 0.25834439]
#  [0.46702241 0.53297759]]
# Novice start prob for 4 users:  [1.00000000e+000 7.84452785e-188]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.481185264006
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264006
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216927000174
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6893.5563871109325
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (4800,) : [800, 800, 800, 800, 800, 800]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.53297741 0.46702259]
#  [0.25834428 0.74165572]]
# Expert HMM start prob for 5 users:  [7.7437073e-188 1.0000000e+000]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.53297741 0.46702259]
#  [0.25834428 0.74165572]]
# Novice start prob for 5 users:  [7.7437073e-188 1.0000000e+000]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7293.652893823398
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264073
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6893.5563871109325
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000643
# Participant is a Novice for 5 users:

# %% [markdown]
# # Evaluation for last 800 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
    X_test_U2T3 = np.array(df_U2T3['line_type'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (2400,) : [800, 800, 800]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.74295008 0.25704992]
#  [0.2732914  0.7267086 ]]
# Expert HMM start prob for 2 users:  [0.65527063 0.34472937]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.69406057 0.30593943]
#  [0.1095406  0.8904594 ]]
# Novice start prob for 2 users:  [0.33504207 0.66495793]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.473684250687
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.478668362469
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.213165859989
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.215662205054
# Participant is an Expert for 2 users:
# ---------------------------------------------------------------------------
# (3200,) : [800, 800, 800, 800]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.72406714 0.27593286]
#  [0.30328751 0.69671249]]
# Expert HMM start prob for 3 users:  [0.47572241 0.52427759]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.85456125 0.14543875]
#  [0.21587876 0.78412124]]
# Novice start prob for 3 users:  [0.73307382 0.26692618]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.476985064576
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.47150573855
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.2148177943345
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.215986469013
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (4000,) : [800, 800, 800, 800, 800]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.70668074 0.29331926]
#  [0.24308571 0.75691429]]
# Expert HMM start prob for 4 users:  [0.36912765 0.63087235]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.83102906 0.16897094]
#  [0.20246243 0.79753757]]
# Novice start prob for 4 users:  [0.79440076 0.20559924]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.4783088317
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.469191469588
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.213447510071
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216243414498
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (4800,) : [800, 800, 800, 800, 800, 800]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.69740664 0.30259336]
#  [0.22332957 0.77667043]]
# Expert HMM start prob for 5 users:  [0.30429389 0.69570611]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.78367343 0.21632657]
#  [0.17364482 0.82635518]]
# Novice start prob for 5 users:  [0.17241201 0.82758799]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.478971043334
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.48007886556
# Participant is an Expert for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.21264172474
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.210134066157
# Participant is a Novice for 5 users:

# %% [markdown]
# # Generate dataset for 900 sequences

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 900 else 900
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:900] if len(data) > 900 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-900:] if len(data) > 900 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)


# creating the dataset of the first 100 sequences task 2 novice users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 900 else 900
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:900] if len(data) > 900 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-900:] if len(data) > 900 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 5400
# length of each dataset experts [900, 900, 900, 900, 900, 900]
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 10800
# length of each dataset novices [900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900]

# %% [markdown]
# # Evaluation for first 900 sequence

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
    X_test_U2T3 = np.array(df_U2T3['line_type'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (2700,) : [900, 900, 900]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.7563693  0.2436307 ]
#  [0.45167398 0.54832602]]
# Expert HMM start prob for 2 users:  [1.00000000e+000 8.63662322e-160]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.7563693  0.2436307 ]
#  [0.45167398 0.54832602]]
# Novice start prob for 2 users:  [1.00000000e+000 8.63662322e-160]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.481185264006
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264006
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6893.5563871109325
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000174
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (3600,) : [900, 900, 900, 900]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.5483257  0.4516743 ]
#  [0.24363053 0.75636947]]
# Expert HMM start prob for 3 users:  [8.4249763e-160 1.0000000e+000]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.75636947 0.24363053]
#  [0.4516743  0.5483257 ]]
# Novice start prob for 3 users:  [1.0000000e+000 8.4249763e-160]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7293.652893823398
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264006
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216927000643
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6893.5563871109325
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (4500,) : [900, 900, 900, 900, 900]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.5483255  0.4516745 ]
#  [0.24363042 0.75636958]]
# Expert HMM start prob for 4 users:  [8.30050218e-160 1.00000000e+000]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.5483255  0.4516745 ]
#  [0.24363042 0.75636958]]
# Novice start prob for 4 users:  [8.30050218e-160 1.00000000e+000]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7293.652893823398
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264073
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216927000643
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6893.5563871109325
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (5400,) : [900, 900, 900, 900, 900, 900]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.54829325 0.45170675]
#  [0.24358939 0.75641061]]
# Expert HMM start prob for 5 users:  [3.43108218e-170 1.00000000e+000]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.54832537 0.45167463]
#  [0.24363035 0.75636965]]
# Novice start prob for 5 users:  [8.21854953e-160 1.00000000e+000]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.481185264073
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7293.652893823398
# Participant is an Expert for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216927000643
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000643
# Participant is a Novice for 5 users:

# %% [markdown]
# # Evaluation for last 900 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
    X_test_U2T3 = np.array(df_U2T3['line_type'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (2700,) : [900, 900, 900]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.74449331 0.25550669]
#  [0.26181106 0.73818894]]
# Expert HMM start prob for 2 users:  [0.66485912 0.33514088]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.88539419 0.11460581]
#  [0.29031256 0.70968744]]
# Novice start prob for 2 users:  [0.33157538 0.66842462]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.478667357836
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.478703472947
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.213048474486
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.215679830285
# Participant is an Expert for 2 users:
# ---------------------------------------------------------------------------
# (3600,) : [900, 900, 900, 900]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.71812738 0.28187262]
#  [0.27172309 0.72827691]]
# Expert HMM start prob for 3 users:  [0.25209916 0.74790084]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.85249916 0.14750084]
#  [0.20174658 0.79825342]]
# Novice start prob for 3 users:  [0.33226357 0.66773643]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.471005858218
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.473377165822
# Participant is an Expert for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.21182968638
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.213012459047
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (4500,) : [900, 900, 900, 900, 900]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.7786679 0.2213321]
#  [0.2867852 0.7132148]]
# Expert HMM start prob for 4 users:  [0.38741133 0.61258867]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.82687984 0.17312016]
#  [0.19486909 0.80513091]]
# Novice start prob for 4 users:  [0.40960696 0.59039304]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.474640793993
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.475087784111
# Participant is an Expert for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.2153792446215
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.213867611098
# Participant is a Novice for 4 users:
# ---------------------------------------------------------------------------
# (5400,) : [900, 900, 900, 900, 900, 900]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.69871971 0.30128029]
#  [0.21128761 0.78871239]]
# Expert HMM start prob for 5 users:  [0.6794967 0.3205033]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.82075415 0.17924585]
#  [0.21034555 0.78965445]]
# Novice start prob for 5 users:  [0.55751896 0.44248104]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.478813904811
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.475696248397
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.215735271535
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.215043230479
# Participant is a Novice for 5 users:

# %% [markdown]
# # Generate dataset for 1000 sequences

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 1000 else 1000
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:1000] if len(data) > 1000 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-1000:] if len(data) > 1000 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)


# creating the dataset of the first 100 sequences task 2 novice users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 1000 else 1000
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:1000] if len(data) > 1000 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-1000:] if len(data) > 1000 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 6000
# length of each dataset experts [1000, 1000, 1000, 1000, 1000, 1000]
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 12000
# length of each dataset novices [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]

# %% [markdown]
# # Evaluation for first 1000 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
    X_test_U2T3 = np.array(df_U2T3['line_type'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (3000,) : [1000, 1000, 1000]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.54034954 0.45965046]
#  [0.23981932 0.76018068]]
# Expert HMM start prob for 2 users:  [6.49543792e-152 1.00000000e+000]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.76018068 0.23981932]
#  [0.45965046 0.54034954]]
# Novice start prob for 2 users:  [1.00000000e+000 6.49543792e-152]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7293.652893823398
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7293.652893823398
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6893.5563871109325
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000174
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (4000,) : [1000, 1000, 1000, 1000]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.76018084 0.23981916]
#  [0.45965075 0.54034925]]
# Expert HMM start prob for 3 users:  [1.00000000e+000 6.34941101e-152]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.76018084 0.23981916]
#  [0.45965075 0.54034925]]
# Novice start prob for 3 users:  [1.00000000e+000 6.34941101e-152]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.481185264006
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264006
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.216927000174
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000174
# Participant is a Novice for 3 users:
# ---------------------------------------------------------------------------
# (5000,) : [1000, 1000, 1000, 1000, 1000]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.54034909 0.45965091]
#  [0.23981906 0.76018094]]
# Expert HMM start prob for 4 users:  [6.26337982e-152 1.00000000e+000]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.76018094 0.23981906]
#  [0.45965091 0.54034909]]
# Novice start prob for 4 users:  [1.00000000e+000 6.26337982e-152]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7293.652893823398
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264006
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6893.5563871109325
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.216927000174
# Participant is a Novice for 4 users:
# ---------------------------------------------------------------------------
# (6000,) : [1000, 1000, 1000, 1000, 1000, 1000]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.76024469 0.23975531]
#  [0.45969746 0.54030254]]
# Expert HMM start prob for 5 users:  [1.00000000e+000 1.56656095e-168]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.54030254 0.45969746]
#  [0.23975531 0.76024469]]
# Novice start prob for 5 users:  [1.56656095e-168 1.00000000e+000]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.481185264006
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.481185264073
# Participant is an Expert for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6893.5563871109325
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6893.5563871109325
# Participant is a Novice for 5 users:

# %% [markdown]
# # Evaluation or last 1000 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U4T3_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Experts/U4T3_new.csv')
    X_test_U4T3_new = np.array((df_U4T3_new['line_type']))
    print("X_test_U4T3_new : ", X_test_U4T3_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U4T3_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U4T3_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T3= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task3/Novices/U2T3_new.csv')
    X_test_U2T3 = np.array(df_U2T3['line_type'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T3.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T3.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (3000,) : [1000, 1000, 1000]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.74339082 0.25660918]
#  [0.24650968 0.75349032]]
# Expert HMM start prob for 2 users:  [0.27725262 0.72274738]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.8839287  0.1160713 ]
#  [0.26505185 0.73494815]]
# Novice start prob for 2 users:  [0.66129902 0.33870098]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.471835326633
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.473537459165
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.212243044347
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.215643459736
# Participant is an Expert for 2 users:
# ---------------------------------------------------------------------------
# (4000,) : [1000, 1000, 1000, 1000]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.72400643 0.27599357]
#  [0.2694007  0.7305993 ]]
# Expert HMM start prob for 3 users:  [0.1925087 0.8074913]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.85143322 0.14856678]
#  [0.19145422 0.80854578]]
# Novice start prob for 3 users:  [0.74513481 0.25486519]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.468597381312
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.479419526335
# Participant is an Expert for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.21063184736
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.211877393059
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (5000,) : [1000, 1000, 1000, 1000, 1000]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.71283691 0.28716309]
#  [0.2095012  0.7904988 ]]
# Expert HMM start prob for 4 users:  [0.33231631 0.66768369]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.81435827 0.18564173]
#  [0.17449226 0.82550774]]
# Novice start prob for 4 users:  [0.40607637 0.59392363]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.473378493697
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.475018751993
# Participant is an Expert for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.213013123531
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.21383307253
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (6000,) : [1000, 1000, 1000, 1000, 1000, 1000]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.69481692 0.30518308]
#  [0.2057203  0.7942797 ]]
# Expert HMM start prob for 5 users:  [0.27457589 0.72542411]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.81643657 0.18356343]
#  [0.2086121  0.7913879 ]]
# Novice start prob for 5 users:  [0.66221441 0.33778559]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U4T3_new :  (3157,)
#
# Probability of Expert at Task 2:
# -7268.479245965857
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -7268.4786403917815
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -6868.212201141701
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -6868.215648162423
# Participant is an Expert for 5 users:
