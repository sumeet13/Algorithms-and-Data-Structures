# %%
import numpy as np
from hmmlearn import hmm
import pandas as pd
import csv
import pathlib
import sys
sys.path.insert(0, '/Users/smaan/ml/FileParser')
import CONSTANTS, util

# %% [markdown]
# I would train 6 HMM models. 3 for experts(who have got task correct) and 3 for novices(who got their task incorrect).
# I am using Gaussian HMM because the value for change_column is continuous in nature.

# %%
paths = [CONSTANTS.path_to_csv_per_user_correctness_training,CONSTANTS.path_to_csv_per_user_correctness_test]

X_train_novices_task2 = np.array([])
len_train_novices_task2 = []
X_test_novices_task2 = np.array([])
len_test_novices_task2 = []
datasets_novices_task2 = [X_train_novices_task2, X_test_novices_task2]
len_datasets_novices_task2 =[len_train_novices_task2, len_test_novices_task2]

X_train_novices_task3 = np.array([])
len_train_novices_task3 = []
X_test_novices_task3 = np.array([])
len_test_novices_task3 = []
datasets_novices_task3 = [X_train_novices_task3, X_test_novices_task3]
len_datasets_novices_task3 =[len_train_novices_task3, len_test_novices_task3]

X_train_novices_task4 = np.array([])
len_train_novices_task4 = []
X_test_novices_task4 = np.array([])
len_test_novices_task4 = []
datasets_novices_task4 = [X_train_novices_task4, X_test_novices_task4]
len_datasets_novices_task4 =[len_train_novices_task4, len_test_novices_task4]


X_train_experts_task2 = np.array([])
len_train_experts_task2 = []
X_test_experts_task2 = np.array([])
len_test_experts_task2 = []
datasets_experts_task2 = [X_train_experts_task2, X_test_experts_task2]
len_datasets_experts_task2 =[len_train_experts_task2, len_test_experts_task2]

X_train_experts_task3 = np.array([])
len_train_experts_task3 = []
X_test_experts_task3 = np.array([])
len_test_experts_task3 = []
datasets_experts_task3 = [X_train_experts_task3, X_test_experts_task3]
len_datasets_experts_task3 =[len_train_experts_task3, len_test_experts_task3]

X_train_experts_task4 = np.array([])
len_train_experts_task4 = []
X_test_experts_task4 = np.array([])
len_test_experts_task4 = []
datasets_experts_task4 = [X_train_experts_task4, X_test_experts_task4]
len_datasets_experts_task4 =[len_train_experts_task4, len_test_experts_task4]

for i in range(len(paths)):
    current_directory = pathlib.Path(paths[i])
    
    for directory in current_directory.glob('**/*'):
        
        try:
            if "Task2" in str(directory) and "Experts" in str(directory) and "new" in str(directory):

                print(("T2 and Experts" + str(directory)))
                df = pd.read_csv(directory)

                X = np.array(df['change_column'])
                print((X.shape))
                print(("before [datasets_experts_task2[i]", len(datasets_experts_task2[i])))
                print((datasets_experts_task2[i]))


                datasets_experts_task2[i]= np.concatenate([datasets_experts_task2[i],X])

                print(("after datasets_experts_task2[i]:", len(datasets_experts_task2[i])))
                if len(X) == 0:
                    continue
                len_datasets_experts_task2[i].append(len(X))
                
            elif "Task3" in str(directory) and "Experts" in str(directory) and "new" in str(directory):
                print(("T3 and Experts" +  str(directory)))
                df = pd.read_csv(directory)
                X = np.array(df['change_column'])
                print((X.shape))
                print(("before [datasets_experts_task3[i]",  len(datasets_experts_task3[i])))
                datasets_experts_task3[i]= np.concatenate([datasets_experts_task3[i],X])
                
                print(("after datasets_experts_task3[i]:", len(datasets_experts_task3[i])))
                if len(X) == 0:
                    continue
                len_datasets_experts_task3[i].append(len(X))
                
            elif "Task4" in str(directory) and "Experts" in str(directory) and "new" in str(directory):
                print(("T4 and Experts" + str(directory)))
                df = pd.read_csv(directory)
                X = np.array(df['change_column'])
                print((X.shape))
                print(("before [datasets_experts_task4[i]", len(datasets_experts_task4[i])))
                datasets_experts_task4[i]= np.concatenate([datasets_experts_task4[i],X])
                
                print(("after datasets_experts_task4[i]:", len(datasets_experts_task4[i])))
                if len(X) == 0:
                    continue
                len_datasets_experts_task4[i].append(len(X))
                
            elif "Task2" in str(directory) and "Novices" in str(directory) and "new" in str(directory):
                print(("T2 and Novices" + str(directory)))
                df = pd.read_csv(directory)
                X = np.array(df['change_column'])
                print((X.shape))
                print(("before [datasets_novices_task2[i]", len(datasets_novices_task2[i])))
                datasets_novices_task2[i] = np.concatenate([datasets_novices_task2[i],X])
                
                print(("after datasets_novices_task2[i]:", len(datasets_novices_task2[i])))
                if len(X) == 0:
                    continue
                len_datasets_novices_task2[i].append(len(X))
                            
                
            elif "Task3" in str(directory) and "Novices" in str(directory) and "new" in str(directory):
                print(("T3 and Novices" + str(directory)))
                df = pd.read_csv(directory)
                X = np.array(df['change_column'])
                print((X.shape))
                print(("before [datasets_novices_task3[i]", len(datasets_novices_task3[i])))
                datasets_novices_task3[i] = np.concatenate([datasets_novices_task3[i],X])
                
                print(("after datasets_novices_task3[i]:", len(datasets_novices_task3[i])))
                if len(X) == 0:
                    continue
                len_datasets_novices_task3[i].append(len(X))
                
            elif "Task4" in str(directory) and "Novices" in str(directory) and "new" in str(directory):
                print(("T4 and Novices" + str(directory)))
                df = pd.read_csv(directory)
                X = np.array(df['change_column'])
                print((X.shape))
                print(("before [datasets_novices_task4[i]",  len(datasets_novices_task4[i])))
                datasets_novices_task4[i] = np.concatenate([datasets_novices_task4[i],X])
                
                print(("after datasets_novices_task4[i]:",  len(datasets_novices_task4[i])))
                if len(X) == 0:
                    continue
                len_datasets_novices_task4[i].append(len(X))
            
        except Exception as e:
            print(e)
            print(("Error!", directory))
# Out:
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U30T3_new.csv
# (21969,)
# ('before [datasets_novices_task3[i]', 0)
# ('after datasets_novices_task3[i]:', 21969)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U24T3_new.csv
# (18857,)
# ('before [datasets_novices_task3[i]', 21969)
# ('after datasets_novices_task3[i]:', 40826)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U11T3_new.csv
# (23303,)
# ('before [datasets_novices_task3[i]', 40826)
# ('after datasets_novices_task3[i]:', 64129)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U29T3_new.csv
# (20278,)
# ('before [datasets_novices_task3[i]', 64129)
# ('after datasets_novices_task3[i]:', 84407)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U7T3_new.csv
# (17326,)
# ('before [datasets_novices_task3[i]', 84407)
# ('after datasets_novices_task3[i]:', 101733)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U22T3_new.csv
# (15495,)
# ('before [datasets_novices_task3[i]', 101733)
# ('after datasets_novices_task3[i]:', 117228)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U28T3_new.csv
# (22456,)
# ('before [datasets_novices_task3[i]', 117228)
# ('after datasets_novices_task3[i]:', 139684)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U23T3_new.csv
# (19533,)
# ('before [datasets_novices_task3[i]', 139684)
# ('after datasets_novices_task3[i]:', 159217)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U3T3_new.csv
# (15156,)
# ('before [datasets_novices_task3[i]', 159217)
# ('after datasets_novices_task3[i]:', 174373)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U13T3_new.csv
# (23102,)
# ('before [datasets_novices_task3[i]', 174373)
# ('after datasets_novices_task3[i]:', 197475)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U5T3_new.csv
# (18278,)
# ('before [datasets_novices_task3[i]', 197475)
# ('after datasets_novices_task3[i]:', 215753)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Novices/U8T3_new.csv
# (22267,)
# ('before [datasets_novices_task3[i]', 215753)
# ('after datasets_novices_task3[i]:', 238020)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Experts/U25T3_new.csv
# (27264,)
# ('before [datasets_experts_task3[i]', 0)
# ('after datasets_experts_task3[i]:', 27264)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Experts/U31T3_new.csv
# (33450,)
# ('before [datasets_experts_task3[i]', 27264)
# ('after datasets_experts_task3[i]:', 60714)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Experts/U26T3_new.csv
# (26026,)
# ('before [datasets_experts_task3[i]', 60714)
# ('after datasets_experts_task3[i]:', 86740)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Experts/U27T3_new.csv
# (29815,)
# ('before [datasets_experts_task3[i]', 86740)
# ('after datasets_experts_task3[i]:', 116555)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task3/Experts/U9T3_new.csv
# (32066,)
# ('before [datasets_experts_task3[i]', 116555)
# ('after datasets_experts_task3[i]:', 148621)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Novices/U13T4_new.csv
# (39190,)
# ('before [datasets_novices_task4[i]', 0)
# ('after datasets_novices_task4[i]:', 39190)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Novices/U5T4_new.csv
# (36917,)
# ('before [datasets_novices_task4[i]', 39190)
# ('after datasets_novices_task4[i]:', 76107)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Novices/U29T4_new.csv
# (38199,)
# ('before [datasets_novices_task4[i]', 76107)
# ('after datasets_novices_task4[i]:', 114306)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Novices/U11T4_new.csv
# (41125,)
# ('before [datasets_novices_task4[i]', 114306)
# ('after datasets_novices_task4[i]:', 155431)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Novices/U24T4_new.csv
# (34123,)
# ('before [datasets_novices_task4[i]', 155431)
# ('after datasets_novices_task4[i]:', 189554)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Novices/U28T4_new.csv
# (43844,)
# ('before [datasets_novices_task4[i]', 189554)
# ('after datasets_novices_task4[i]:', 233398)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Novices/U31T4_new.csv
# (42989,)
# ('before [datasets_novices_task4[i]', 233398)
# ('after datasets_novices_task4[i]:', 276387)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Novices/U23T4_new.csv
# (37716,)
# ('before [datasets_novices_task4[i]', 276387)
# ('after datasets_novices_task4[i]:', 314103)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Experts/U26T4_new.csv
# (45936,)
# ('before [datasets_experts_task4[i]', 0)
# ('after datasets_experts_task4[i]:', 45936)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Experts/U8T4_new.csv
# (52618,)
# ('before [datasets_experts_task4[i]', 45936)
# ('after datasets_experts_task4[i]:', 98554)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Experts/U27T4_new.csv
# (51268,)
# ('before [datasets_experts_task4[i]', 98554)
# ('after datasets_experts_task4[i]:', 149822)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Experts/U9T4_new.csv
# (55739,)
# ('before [datasets_experts_task4[i]', 149822)
# ('after datasets_experts_task4[i]:', 205561)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Experts/U30T4_new.csv
# (53833,)
# ('before [datasets_experts_task4[i]', 205561)
# ('after datasets_experts_task4[i]:', 259394)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Experts/U22T4_new.csv
# (46532,)
# ('before [datasets_experts_task4[i]', 259394)
# ('after datasets_experts_task4[i]:', 305926)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Experts/U7T4_new.csv
# (44900,)
# ('before [datasets_experts_task4[i]', 305926)
# ('after datasets_experts_task4[i]:', 350826)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Experts/U25T4_new.csv
# (46916,)
# ('before [datasets_experts_task4[i]', 350826)
# ('after datasets_experts_task4[i]:', 397742)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task4/Experts/U6T4_new.csv
# (49858,)
# ('before [datasets_experts_task4[i]', 397742)
# ('after datasets_experts_task4[i]:', 447600)
# T2 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U7T2_new.csv
# (60102,)
# ('before [datasets_novices_task2[i]', 0)
# ('after datasets_novices_task2[i]:', 60102)
# T2 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U22T2_new.csv
# (57584,)
# ('before [datasets_novices_task2[i]', 60102)
# ('after datasets_novices_task2[i]:', 117686)
# T2 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U29T2_new.csv
# (66855,)
# ('before [datasets_novices_task2[i]', 117686)
# ('after datasets_novices_task2[i]:', 184541)
# T2 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U30T2_new.csv
# (65112,)
# ('before [datasets_novices_task2[i]', 184541)
# ('after datasets_novices_task2[i]:', 249653)
# T2 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U24T2_new.csv
# (62252,)
# ('before [datasets_novices_task2[i]', 249653)
# ('after datasets_novices_task2[i]:', 311905)
# T2 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U11T2_new.csv
# (70262,)
# ('before [datasets_novices_task2[i]', 311905)
# ('after datasets_novices_task2[i]:', 382167)
# T2 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U23T2_new.csv
# (62322,)
# ('before [datasets_novices_task2[i]', 382167)
# ('after datasets_novices_task2[i]:', 444489)
# T2 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U28T2_new.csv
# (69513,)
# ('before [datasets_novices_task2[i]', 444489)
# ('after datasets_novices_task2[i]:', 514002)
# T2 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U10T2_new.csv
# (69124,)
# ('before [datasets_novices_task2[i]', 514002)
# ('after datasets_novices_task2[i]:', 583126)
# T2 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U8T2_new.csv
# (63768,)
# ('before [datasets_novices_task2[i]', 583126)
# ('after datasets_novices_task2[i]:', 646894)
# T2 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U13T2_new.csv
# (69513,)
# ('before [datasets_novices_task2[i]', 646894)
# ('after datasets_novices_task2[i]:', 716407)
# T2 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Novices/U26T2_new.csv
# (61945,)
# ('before [datasets_novices_task2[i]', 716407)
# ('after datasets_novices_task2[i]:', 778352)
# T2 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Experts/U6T2_new.csv
# (78280,)
# ('before [datasets_experts_task2[i]', 0)
# []
# ('after datasets_experts_task2[i]:', 78280)
# T2 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Experts/U25T2_new.csv
# (75609,)
# ('before [datasets_experts_task2[i]', 78280)
# [ 0.  3.  3. ...  7.  0. -8.]
# ('after datasets_experts_task2[i]:', 153889)
# T2 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Experts/U31T2_new.csv
# (81123,)
# ('before [datasets_experts_task2[i]', 153889)
# [ 0.  3.  3. ...  7. 21. -2.]
# ('after datasets_experts_task2[i]:', 235012)
# T2 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Experts/U5T2_new.csv
# (74668,)
# ('before [datasets_experts_task2[i]', 235012)
# [  0.   3.   3. ...   2. -21.  15.]
# ('after datasets_experts_task2[i]:', 309680)
# T2 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Experts/U9T2_new.csv
# (82666,)
# ('before [datasets_experts_task2[i]', 309680)
# [ 0.  3.  3. ... -3. -1.  4.]
# ('after datasets_experts_task2[i]:', 392346)
# T2 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Training/Task2/Experts/U27T2_new.csv
# (79610,)
# ('before [datasets_experts_task2[i]', 392346)
# [0. 3. 3. ... 9. 6. 7.]
# ('after datasets_experts_task2[i]:', 471956)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task3/Novices/U1T3_new.csv
# (713,)
# ('before [datasets_novices_task3[i]', 0)
# ('after datasets_novices_task3[i]:', 713)
# T3 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task3/Novices/U2T3_new.csv
# (2977,)
# ('before [datasets_novices_task3[i]', 713)
# ('after datasets_novices_task3[i]:', 3690)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task3/Experts/U6T3_new.csv
# (5865,)
# ('before [datasets_experts_task3[i]', 0)
# ('after datasets_experts_task3[i]:', 5865)
# T3 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task3/Experts/U4T3_new.csv
# (3157,)
# ('before [datasets_experts_task3[i]', 5865)
# ('after datasets_experts_task3[i]:', 9022)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task4/Novices/U3T4_new.csv
# (7015,)
# ('before [datasets_novices_task4[i]', 0)
# ('after datasets_novices_task4[i]:', 7015)
# T4 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task4/Novices/U2T4_new.csv
# (8179,)
# ('before [datasets_novices_task4[i]', 7015)
# ('after datasets_novices_task4[i]:', 15194)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task4/Experts/U4T4_new.csv
# (10491,)
# ('before [datasets_experts_task4[i]', 0)
# ('after datasets_experts_task4[i]:', 10491)
# T4 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task4/Experts/U1T4_new.csv
# (9331,)
# ('before [datasets_experts_task4[i]', 10491)
# ('after datasets_experts_task4[i]:', 19822)
# T2 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task2/Novices/U1T2_new.csv
# (12185,)
# ('before [datasets_novices_task2[i]', 0)
# ('after datasets_novices_task2[i]:', 12185)
# T2 and Novices/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task2/Novices/U2T2_new.csv
# (12901,)
# ('before [datasets_novices_task2[i]', 12185)
# ('after datasets_novices_task2[i]:', 25086)
# T2 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task2/Experts/U3T2_new.csv
# (14160,)
# ('before [datasets_experts_task2[i]', 0)
# []
# ('after datasets_experts_task2[i]:', 14160)
# T2 and Experts/Users/smaan/Documents/eye_tracking_files/CSV_files/All_CSVs/Test/Task2/Experts/U4T2_new.csv
# (15143,)
# ('before [datasets_experts_task2[i]', 14160)
# [ 0.  3.  3. ... -4.  5. 11.]
# ('after datasets_experts_task2[i]:', 29303)

# %% [markdown]
# # Train a HMM for Experts at Task 2

# %%
# Train a HMM for the Experts in Task 2

states = ["Expert", "Novice"]
n_states = len(states)

df_U5T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task2/Experts/U5T2_new.csv')
df_U6T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task2/Experts/U6T2_new.csv')
df_U9T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task2/Experts/U9T2_new.csv')
df_U25T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task2/Experts/U25T2_new.csv')
df_U27T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task2/Experts/U27T2_new.csv')
df_U31T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task2/Experts/U31T2_new.csv')


X_train_U5T2 = np.array((df_U5T2['change_column']))
X_train_U6T2 = np.array((df_U6T2['change_column']))
X_train_U9T2 = np.array((df_U9T2['change_column']))
X_train_U25T2 = np.array((df_U25T2['change_column']))
X_train_U27T2 = np.array((df_U27T2['change_column']))
X_train_U31T2 = np.array((df_U31T2['change_column']))


X_train_expert = np.concatenate([X_train_U5T2, X_train_U6T2,X_train_U9T2,X_train_U25T2,X_train_U27T2,X_train_U31T2]).T
lengths = [len(X_train_U5T2), len(X_train_U6T2), len(X_train_U9T2), len(X_train_U25T2), len(X_train_U27T2), len(X_train_U31T2)]

# Learning model parameters: transmission & emission matrices

    
model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
model_train_experts_task2.fit(X_train_expert.reshape(-1,1), lengths)
    
    
print("Expert HMM: Transition Probabilities: ")
print(model_train_experts_task2.transmat_)

print("Expert HMM start prob:", model_train_experts_task2.startprob_)
# Out:
# Expert HMM: Transition Probabilities:
# [[0.8641028  0.1358972 ]
#  [0.25704444 0.74295556]]
# Expert HMM start prob: [1.00000000e+00 4.04273332e-41]

# %% [markdown]
# # Train a HMM for Novices at Task 2

# %%
states = ["Expert", "Novice"]
n_states = len(states)

df_U7T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task2/Novices/U7T2_new.csv')
df_U8T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task2/Novices/U8T2_new.csv')
df_U10T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task2/Novices/U10T2_new.csv')
df_U11T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task2/Novices/U11T2_new.csv')
df_U13T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task2/Novices/U13T2_new.csv')
df_U22T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_training+'/Task2/Novices/U22T2_new.csv')


X_train_U7T2 = np.array((df_U7T2['change_column']))
X_train_U8T2 = np.array((df_U8T2['change_column']))
X_train_U10T2 = np.array((df_U10T2['change_column']))
X_train_U11T2 = np.array((df_U11T2['change_column']))
X_train_U13T2 = np.array((df_U13T2['change_column']))
X_train_U22T2 = np.array((df_U22T2['change_column']))

X_train_novices = np.concatenate([X_train_U7T2,X_train_U8T2 ,X_train_U10T2, X_train_U11T2, X_train_U11T2, X_train_U22T2]).T
lengths_novices = [len(X_train_U7T2), len(X_train_U8T2), len(X_train_U10T2), len(X_train_U11T2), len(X_train_U11T2), len(X_train_U22T2)]

# Learning model parameters: transmission & emission matrices


model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
model_train_novices_task2.fit(X_train_novices.reshape(-1,1), lengths_novices)
    
    
print("Novice HMM: Transition Probabilities: ")
print(model_train_novices_task2.transmat_)
print("Novice start prob:", model_train_novices_task2.startprob_)
# Out:
# Novice HMM: Transition Probabilities:
# [[0.86366456 0.13633544]
#  [0.26958423 0.73041577]]
# Novice start prob: [1.00000000e+00 1.23814006e-39]

# %% [markdown]
# # Evaluation of Expert Participant on both the HMMs

# %%
print("\n--------------------------------- Model: Expert -----------------------------------")
print("Testing with Expert User")
model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


# Rainy
model_test_expert.startprob_ = model_train_experts_task2.startprob_

model_test_expert.transprob_ = np.array([
  [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
  [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
])



df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
# Estimate model parameters.
model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1,1))


# Find most likely state (hidden) sequence corresponding to the observation sequence
# We use the following function "decode": the first argument should be the observation sequence (matrix)
logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U3T2_new.reshape(-1,1), algorithm="viterbi")




print("\nProbability of Expert at Task 2:")
print(logprob_expert_task2)


print("\n--------------------------------- Model: Novice -----------------------------------")



model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


# Rainy
model_test_novice.startprob_ = model_train_novices_task2.startprob_

model_test_novice.transprob_ = np.array([
  [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
  [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
])



# df_U22T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U22T2.csv')
# X_test_U2T2 = np.array([df_U22T2['token_type']]).T
# Estimate model parameters.
model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1,1))


# Find most likely state (hidden) sequence corresponding to the observation sequence
# We use the following function "decode": the first argument should be the observation sequence (matrix)
logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U3T2_new.reshape(-1,1), algorithm="viterbi")




print("\nProbability of Novice at Task 2:")
print(logprob_novice_task2)


if logprob_expert_task2 > logprob_novice_task2:
    print("Participant is an Expert")
    
else:
    print("Participant is an Novice")
# Out:
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
#
# Probability of Expert at Task 2:
# -51577.95146189383
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51253.04369507151
# Participant is an Novice

# %%
print("\n--------------------------------- Model: Expert -----------------------------------")
print("Testing with Novice User")
model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


# Rainy
model_test_expert.startprob_ = model_train_experts_task2.startprob_

model_test_expert.transprob_ = np.array([
  [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
  [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
])



df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')

X_test_U2T2 = np.array((df_U2T2['change_column']))
# Estimate model parameters.
model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


# Find most likely state (hidden) sequence corresponding to the observation sequence
# We use the following function "decode": the first argument should be the observation sequence (matrix)
logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




print("\nProbability of Expert at Task 2:")
print(logprob_expert_task2)


print("\n--------------------------------- Model: Novice -----------------------------------")



model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


# Rainy
model_test_novice.startprob_ = model_train_novices_task2.startprob_

model_test_novice.transprob_ = np.array([
  [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
  [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
])




# Estimate model parameters.
model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


# Find most likely state (hidden) sequence corresponding to the observation sequence
# We use the following function "decode": the first argument should be the observation sequence (matrix)
logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




print("\nProbability of Novice at Task 2:")
print(logprob_novice_task2)


if logprob_expert_task2 > logprob_novice_task2:
    print("Participant is an Expert")
    
else:
    print("Participant is a Novice")
# Out:
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46891.27241848394
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46888.078927631585
# Participant is a Novice

# %% [markdown]
# # Adding all users for Experts and Task 2

# %%
# Train a HMM for the Experts in Task 2

states = ["Expert", "Novice"]
n_states = len(states)

X_train_experts_task2 = np.array(datasets_experts_task2[0])

print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])


# Learning model parameters: transmission & emission matrices

    
model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), len_datasets_experts_task2[0])
    
    
print("Expert HMM: Transition Probabilities: ")
print(model_train_experts_task2.transmat_)

print("Expert HMM start prob:", model_train_experts_task2.startprob_)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# Expert HMM: Transition Probabilities:
# [[0.86409005 0.13590995]
#  [0.25703969 0.74296031]]
# Expert HMM start prob: [1.00000000e+00 1.22752674e-41]

# %% [markdown]
# # Adding all users for Novices and Task 2

# %%
states = ["Expert", "Novice"]
n_states = len(states)

X_train_novices_task2 = np.array(datasets_novices_task2[0])

print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

# Learning model parameters: transmission & emission matrices

    
model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), len_datasets_novices_task2[0])
    
    
print("Novice HMM: Transition Probabilities: ")
print(model_train_novices_task2.transmat_)
print("Novice start prob:", model_train_novices_task2.startprob_)
# Out:
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# Novice HMM: Transition Probabilities:
# [[0.7313859  0.2686141 ]
#  [0.13613022 0.86386978]]
# Novice start prob: [6.94913931e-44 1.00000000e+00]

# %% [markdown]
# # Evaluation for experts at task 2

# %%
print("\n--------------------------------- Model: Expert -----------------------------------")
print("Testing with Expert User")
model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


# Rainy
model_test_expert.startprob_ = model_train_experts_task2.startprob_

model_test_expert.transprob_ = np.array([
  [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
  [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
])



df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

# Estimate model parameters.
model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1,1))


# Find most likely state (hidden) sequence corresponding to the observation sequence
# We use the following function "decode": the first argument should be the observation sequence (matrix)
logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U3T2_new.reshape(-1,1), algorithm="viterbi")




print("\nProbability of Expert at Task 2:")
print(logprob_expert_task2)


print("\n--------------------------------- Model: Novice -----------------------------------")



model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


# Rainy
model_test_novice.startprob_ = model_train_novices_task2.startprob_

model_test_novice.transprob_ = np.array([
  [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
  [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
])



df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
X_test_U2T2 = np.array((df_U2T2['change_column']))
# Estimate model parameters.
model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1,1))


# Find most likely state (hidden) sequence corresponding to the observation sequence
# We use the following function "decode": the first argument should be the observation sequence (matrix)
logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U3T2_new.reshape(-1,1), algorithm="viterbi")




print("\nProbability of Novice at Task 2:")
print(logprob_novice_task2)


if logprob_expert_task2 > logprob_novice_task2:
    print("Participant is an Expert")
    
else:
    print("Participant is an Novice")
# Out:
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.00825227692
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51253.04369458986
# Participant is an Expert

# %% [markdown]
# # Model evaluation of novice at task 2

# %%
print("\n--------------------------------- Model: Expert -----------------------------------")
print("Testing with Novice User")
model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


# Rainy
model_test_expert.startprob_ = model_train_experts_task2.startprob_

model_test_expert.transprob_ = np.array([
  [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
  [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
])



df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
X_test_U2T2 = np.array(df_U2T2['change_column'])
# Estimate model parameters.
model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


# Find most likely state (hidden) sequence corresponding to the observation sequence
# We use the following function "decode": the first argument should be the observation sequence (matrix)
logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




print("\nProbability of Expert at Task 2:")
print(logprob_expert_task2)


print("\n--------------------------------- Model: Novice -----------------------------------")



model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


# Rainy
model_test_novice.startprob_ = model_train_novices_task2.startprob_

model_test_novice.transprob_ = np.array([
  [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
  [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
])




# Estimate model parameters.
model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


# Find most likely state (hidden) sequence corresponding to the observation sequence
# We use the following function "decode": the first argument should be the observation sequence (matrix)
logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




print("\nProbability of Novice at Task 2:")
print(logprob_novice_task2)


if logprob_expert_task2 > logprob_novice_task2:
    print("Participant is an Expert")
    
else:
    print("Participant is a Novice")
# Out:
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46891.27241848394
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47061.36130073741
# Participant is an Expert

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 100 else 100
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:100] if len(data) > 100 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-100:] if len(data) > 100 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 600
# length of each dataset experts [100, 100, 100, 100, 100, 100]

# %% [markdown]
# # Creating dataset for novice users

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 100 else 100
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:100] if len(data) > 100 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-100:] if len(data) > 100 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 1200
# length of each dataset novices [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100]

# %% [markdown]
# # Evaluation by increasing the users for first 100 sequences of change_column

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U1T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U1T2_new.csv')
    X_test_U1T2_new = np.array((df_U1T2_new['change_column']))
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U1T2_new.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U1T2_new.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U1T2_new.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U1T2_new.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (300,) : [100, 100, 100]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.52044458 0.47955542]
#  [0.56003183 0.43996817]]
# Expert HMM start prob for 2 users:  [1.00000000e+00 2.37988267e-11]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.44333106 0.55666894]
#  [0.49169601 0.50830399]]
# Novice start prob for 2 users:  [2.53928096e-11 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51574.51078630409
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51253.04369453963
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -44409.89833780732
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -44409.898337593215
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (400,) : [100, 100, 100, 100]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.51085599 0.48914401]
#  [0.55034191 0.44965809]]
# Expert HMM start prob for 3 users:  [1.00000000e+00 4.13550799e-12]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.51085599 0.48914401]
#  [0.55034191 0.44965809]]
# Novice start prob for 3 users:  [1.00000000e+00 4.13550799e-12]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51253.043694523
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51577.9514613738
# Participant is an Expert for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -44406.60783234705
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -44406.60783234705
# Participant is a Novice for 3 users:
# ---------------------------------------------------------------------------
# (500,) : [100, 100, 100, 100, 100]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.45527305 0.54472695]
#  [0.48684674 0.51315326]]
# Expert HMM start prob for 4 users:  [6.64743361e-13 1.00000000e+00]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.52309678 0.47690322]
#  [0.54726061 0.45273939]]
# Novice start prob for 4 users:  [1.00000000e+00 6.14822312e-13]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.00825173728
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51253.04369461755
# Participant is an Expert for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -44266.66573107007
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -44574.81954748667
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (600,) : [100, 100, 100, 100, 100, 100]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.46023261 0.53976739]
#  [0.48479648 0.51520352]]
# Expert HMM start prob for 5 users:  [1.0571519e-13 1.0000000e+00]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.46023261 0.53976739]
#  [0.48479648 0.51520352]]
# Novice start prob for 5 users:  [1.0571519e-13 1.0000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51403.09902749841
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51403.09902749841
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -44409.898337906656
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -44409.898337906656
# Participant is a Novice for 5 users:

# %% [markdown]
# # Evaluation by increasing users for last 100 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U1T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U1T2_new.csv')
    X_test_U1T2_new = np.array((df_U1T2_new['change_column']))
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U1T2_new.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U1T2_new.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U1T2_new.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U1T2_new.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (300,) : [100, 100, 100]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.43641251 0.56358749]
#  [0.28901581 0.71098419]]
# Expert HMM start prob for 2 users:  [1.03835692e-07 9.99999896e-01]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.83598725 0.16401275]
#  [0.40070684 0.59929316]]
# Novice start prob for 2 users:  [2.39064758e-32 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51403.09908640384
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51577.951461414756
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -44269.78169561338
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -44578.4590743278
# Participant is an Expert for 2 users:
# ---------------------------------------------------------------------------
# (400,) : [100, 100, 100, 100]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.84204322 0.15795678]
#  [0.2029476  0.7970524 ]]
# Expert HMM start prob for 3 users:  [0.56794158 0.43205842]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.83930142 0.16069858]
#  [0.31278133 0.68721867]]
# Novice start prob for 3 users:  [0.10427629 0.89572371]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51400.20940388447
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.538542522874
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -44406.968591876015
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -44406.6576926594
# Participant is a Novice for 3 users:
# ---------------------------------------------------------------------------
# (500,) : [100, 100, 100, 100, 100]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.904756   0.095244  ]
#  [0.12497162 0.87502838]]
# Expert HMM start prob for 4 users:  [0.61812646 0.38187354]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.90122754 0.09877246]
#  [0.11637196 0.88362804]]
# Novice start prob for 4 users:  [0.78585222 0.21414778]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.25856823317
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51574.6573481423
# Participant is an Expert for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -44406.82125719928
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -44407.21713800324
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (600,) : [100, 100, 100, 100, 100, 100]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.84608414 0.15391586]
#  [0.14148948 0.85851052]]
# Expert HMM start prob for 5 users:  [0.42515127 0.57484873]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.83758227 0.16241773]
#  [0.12518953 0.87481047]]
# Novice start prob for 5 users:  [0.35651561 0.64348439]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51400.11013357554
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.12387971184
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -44266.9251305697
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -44266.80033639229
# Participant is a Novice for 5 users:

# %% [markdown]
# # generate dataset for sequence 200

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 200 else 200
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:200] if len(data) > 200 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-200:] if len(data) > 200 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)


# creating the dataset of the first 100 sequences task 2 novice users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 200 else 200
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:200] if len(data) > 200 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-200:] if len(data) > 200 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 1200
# length of each dataset experts [200, 200, 200, 200, 200, 200]
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 2400
# length of each dataset novices [200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200]

# %% [markdown]
# # Evaluation by increasing the sequences first 200 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
    X_test_U2T2 = np.array((df_U2T2['change_column']))
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (600,) : [200, 200, 200]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.57706668 0.42293332]
#  [0.05658477 0.94341523]]
# Expert HMM start prob for 2 users:  [3.54638191e-44 1.00000000e+00]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.94322082 0.05677918]
#  [0.42341771 0.57658229]]
# Novice start prob for 2 users:  [1.00000000e+00 2.55615212e-33]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51403.0990273417
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51577.95146189383
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46891.27241833453
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46744.4875684218
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (800,) : [200, 200, 200, 200]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.5786707  0.4213293 ]
#  [0.05594669 0.94405331]]
# Expert HMM start prob for 3 users:  [8.39300438e-45 1.00000000e+00]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.94448661 0.05551339]
#  [0.42022756 0.57977244]]
# Novice start prob for 3 users:  [1.00000000e+00 1.39483629e-34]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51253.04369458986
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.00825227692
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.48756857226
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47057.869952175475
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (1000,) : [200, 200, 200, 200, 200]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.94515125 0.05484875]
#  [0.41851742 0.58148258]]
# Expert HMM start prob for 4 users:  [1.00000000e+00 4.60706765e-46]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.58148258 0.41851742]
#  [0.05484875 0.94515125]]
# Novice start prob for 4 users:  [4.60706765e-46 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51574.51078607835
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51253.04369458986
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.4875684218
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47061.36130073741
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (1200,) : [200, 200, 200, 200, 200, 200]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.94556164 0.05443836]
#  [0.41744919 0.58255081]]
# Expert HMM start prob for 5 users:  [1.00000000e+00 9.41854084e-43]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.58269851 0.41730149]
#  [0.0543819  0.9456181 ]]
# Novice start prob for 5 users:  [1.07586762e-46 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.00825227692
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51253.04369458986
# Participant is an Expert for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46747.525305056406
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47057.869952009794
# Participant is an Expert for 5 users:

# %% [markdown]
# # Evaluation by increasing users last 200

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
    X_test_U2T2 = np.array(df_U2T2['change_column'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (600,) : [200, 200, 200]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.82336244 0.17663756]
#  [0.29806839 0.70193161]]
# Expert HMM start prob for 2 users:  [0.08899664 0.91100336]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.77966205 0.22033795]
#  [0.4066389  0.5933611 ]]
# Novice start prob for 2 users:  [3.55793573e-10 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.03243717236
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51253.043695194785
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -47057.933630202926
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46888.07892778212
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (800,) : [200, 200, 200, 200]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.82198537 0.17801463]
#  [0.16425756 0.83574244]]
# Expert HMM start prob for 3 users:  [0.98595279 0.01404721]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.77583979 0.22416021]
#  [0.21736554 0.78263446]]
# Novice start prob for 3 users:  [0.82307976 0.17692024]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51399.90839789925
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.05900588819
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46888.0847616709
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47058.001062679556
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (1000,) : [200, 200, 200, 200, 200]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.87179839 0.12820161]
#  [0.19906695 0.80093305]]
# Expert HMM start prob for 4 users:  [0.98276121 0.01723879]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.78746778 0.21253222]
#  [0.15087087 0.84912913]]
# Novice start prob for 4 users:  [0.43292017 0.56707983]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.82638523292
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.22692904743
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.49233237929
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46744.71840291091
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (1200,) : [200, 200, 200, 200, 200, 200]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.78962294 0.21037706]
#  [0.17525163 0.82474837]]
# Expert HMM start prob for 5 users:  [0.09326162 0.90673838]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.77757687 0.22242313]
#  [0.15098119 0.84901881]]
# Novice start prob for 5 users:  [0.3483452 0.6516548]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.55853710346
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51400.279600999456
# Participant is an Expert for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46888.119200234614
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46744.60638407519
# Participant is a Novice for 5 users:

# %% [markdown]
# # Generate dataset for 300 sequence

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 300 else 300
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:300] if len(data) > 300 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-300:] if len(data) > 300 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)


# creating the dataset of the first 100 sequences task 2 novice users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 300 else 300
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:300] if len(data) > 300 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-300:] if len(data) > 300 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 1800
# length of each dataset experts [300, 300, 300, 300, 300, 300]
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 3600
# length of each dataset novices [300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300]

# %% [markdown]
# # #valuation for first 300 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
    X_test_U2T2 = np.array(df_U2T2['change_column'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (900,) : [300, 300, 300]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.94636344 0.05363656]
#  [0.35931187 0.64068813]]
# Expert HMM start prob for 2 users:  [1.00000000e+00 3.10611922e-27]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.94636344 0.05363656]
#  [0.35931187 0.64068813]]
# Novice start prob for 2 users:  [1.00000000e+00 3.10611922e-27]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.00825227692
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51253.04369507151
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.4875684218
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46891.27241848394
# Participant is an Expert for 2 users:
# ---------------------------------------------------------------------------
# (1200,) : [300, 300, 300, 300]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.64146778 0.35853222]
#  [0.05348731 0.94651269]]
# Expert HMM start prob for 3 users:  [4.97082648e-28 1.00000000e+00]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.94651269 0.05348731]
#  [0.35853222 0.64146778]]
# Novice start prob for 3 users:  [1.00000000e+00 4.97082648e-28]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51574.51078625446
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.00825227692
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46888.07892739243
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47057.869952175475
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (1500,) : [300, 300, 300, 300, 300]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.94685814 0.05314186]
#  [0.3567247  0.6432753 ]]
# Expert HMM start prob for 4 users:  [1.0000000e+00 7.0531921e-29]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.64303031 0.35696969]
#  [0.05318864 0.94681136]]
# Novice start prob for 4 users:  [2.75075627e-29 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51403.09902752652
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51403.0990273417
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46888.078927631585
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47061.36130073741
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (1800,) : [300, 300, 300, 300, 300, 300]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.64478841 0.35521159]
#  [0.05285328 0.94714672]]
# Expert HMM start prob for 5 users:  [9.97754545e-30 1.00000000e+00]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.64424151 0.35575849]
#  [0.05295752 0.94704248]]
# Novice start prob for 5 users:  [6.25148942e-29 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51403.0990273417
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51399.902966611895
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46747.52530495209
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47057.869952009794
# Participant is an Expert for 5 users:

# %% [markdown]
# # Evaluation for last 300 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
    X_test_U2T2 = np.array(df_U2T2['change_column'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (900,) : [300, 300, 300]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.76302671 0.23697329]
#  [0.17983901 0.82016099]]
# Expert HMM start prob for 2 users:  [0.39874086 0.60125914]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.77476045 0.22523955]
#  [0.37419678 0.62580322]]
# Novice start prob for 2 users:  [1.37518663e-09 9.99999999e-01]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51400.09394213294
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51403.09902817788
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -47058.19602488304
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46747.52530639046
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (1200,) : [300, 300, 300, 300]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.85869276 0.14130724]
#  [0.15218322 0.84781678]]
# Expert HMM start prob for 3 users:  [0.53840492 0.46159508]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.79391942 0.20608058]
#  [0.25044285 0.74955715]]
# Novice start prob for 3 users:  [1.00000000e+00 1.75557779e-29]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.2105302435
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51403.09902752652
# Participant is an Expert for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46888.382499915395
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46744.4875684218
# Participant is a Novice for 3 users:
# ---------------------------------------------------------------------------
# (1500,) : [300, 300, 300, 300, 300]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.87352606 0.12647394]
#  [0.17253137 0.82746863]]
# Expert HMM start prob for 4 users:  [0.58762264 0.41237736]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.78137912 0.21862088]
#  [0.17426073 0.82573927]]
# Novice start prob for 4 users:  [3.79714223e-32 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.14776993285
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51253.04369458986
# Participant is an Expert for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.63509370463
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46891.27241833453
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (1800,) : [300, 300, 300, 300, 300, 300]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.84458374 0.15541626]
#  [0.18066234 0.81933766]]
# Expert HMM start prob for 5 users:  [0.68821551 0.31178449]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.7634024  0.2365976 ]
#  [0.19024292 0.80975708]]
# Novice start prob for 5 users:  [7.13467647e-33 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51574.73366273558
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51253.04369458986
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46888.51711470721
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47061.36130073741
# Participant is an Expert for 5 users:

# %% [markdown]
# # Generate dataset for 400 sequences

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 400 else 400
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:400] if len(data) > 400 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-400:] if len(data) > 400 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)


# creating the dataset of the first 100 sequences task 2 novice users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 400 else 400
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:400] if len(data) > 400 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-400:] if len(data) > 400 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 2400
# length of each dataset experts [400, 400, 400, 400, 400, 400]
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 4800
# length of each dataset novices [400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400, 400]

# %% [markdown]
# # Evaluation for first 400 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
    X_test_U2T2 = np.array(df_U2T2['change_column'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (1200,) : [400, 400, 400]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.64891215 0.35108785]
#  [0.06487525 0.93512475]]
# Expert HMM start prob for 2 users:  [2.19717506e-24 1.00000000e+00]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.93512475 0.06487525]
#  [0.35108785 0.64891215]]
# Novice start prob for 2 users:  [1.00000000e+00 2.19717506e-24]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51577.951461414756
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51403.09902752652
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46891.27241833453
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46747.525305056406
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (1600,) : [400, 400, 400, 400]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.93546822 0.06453178]
#  [0.34963201 0.65036799]]
# Expert HMM start prob for 3 users:  [1.00000000e+00 1.19773256e-28]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.65036799 0.34963201]
#  [0.06453178 0.93546822]]
# Novice start prob for 3 users:  [1.19773256e-28 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51253.04369507151
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51574.51078625446
# Participant is an Expert for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46888.078927631585
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47061.36130073741
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (2000,) : [400, 400, 400, 400, 400]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.65173542 0.34826458]
#  [0.06420976 0.93579024]]
# Expert HMM start prob for 4 users:  [1.73910105e-29 1.00000000e+00]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.65173542 0.34826458]
#  [0.06420976 0.93579024]]
# Novice start prob for 4 users:  [1.73910105e-29 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51399.902966611895
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51403.0990273417
# Participant is an Expert for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -47061.36130073741
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46891.27241833453
# Participant is a Novice for 4 users:
# ---------------------------------------------------------------------------
# (2400,) : [400, 400, 400, 400, 400, 400]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.9357899 0.0642101]
#  [0.348266  0.651734 ]]
# Expert HMM start prob for 5 users:  [1.00000000e+00 1.74224422e-29]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.651734  0.348266 ]
#  [0.0642101 0.9357899]]
# Novice start prob for 5 users:  [1.74224422e-29 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.00825227692
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51253.04369458986
# Participant is an Expert for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46888.078927631585
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47057.869952009794
# Participant is an Expert for 5 users:

# %% [markdown]
# # Evaluation for last 400 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
    X_test_U2T2 = np.array(df_U2T2['change_column'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (1200,) : [400, 400, 400]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.81483845 0.18516155]
#  [0.22657629 0.77342371]]
# Expert HMM start prob for 2 users:  [1.00000000e+00 1.48756222e-20]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.77012872 0.22987128]
#  [0.34474004 0.65525996]]
# Novice start prob for 2 users:  [0.27705336 0.72294664]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.00825227692
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.093168585336
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46891.27241848394
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46888.55450703191
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (1600,) : [400, 400, 400, 400]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.85380086 0.14619914]
#  [0.13065744 0.86934256]]
# Expert HMM start prob for 3 users:  [1.17041345e-17 1.00000000e+00]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.75985006 0.24014994]
#  [0.27009809 0.72990191]]
# Novice start prob for 3 users:  [0.4578369 0.5421631]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.00825226868
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51400.1310144977
# Participant is an Expert for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.48756857226
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46888.385462652295
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (2000,) : [400, 400, 400, 400, 400]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.84906325 0.15093675]
#  [0.13323565 0.86676435]]
# Expert HMM start prob for 4 users:  [1.00000000e+00 2.99124733e-11]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.75521583 0.24478417]
#  [0.23230359 0.76769641]]
# Novice start prob for 4 users:  [0.67025891 0.32974109]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51403.09902736417
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51400.296804248894
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.48756850973
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47058.508670045136
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (2400,) : [400, 400, 400, 400, 400, 400]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.84742883 0.15257117]
#  [0.15737583 0.84262417]]
# Expert HMM start prob for 5 users:  [0.67067722 0.32932278]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.73847948 0.26152052]
#  [0.22908505 0.77091495]]
# Novice start prob for 5 users:  [0.49491129 0.50508871]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.11296711246
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51574.898549750185
# Participant is an Expert for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -47058.50925003663
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46888.35698240453
# Participant is a Novice for 5 users:

# %% [markdown]
# # Generate dataset for 500 sequences

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 500 else 500
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:500] if len(data) > 500 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-500:] if len(data) > 500 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)


# creating the dataset of the first 100 sequences task 2 novice users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 500 else 500
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:500] if len(data) > 500 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-500:] if len(data) > 500 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 3000
# length of each dataset experts [500, 500, 500, 500, 500, 500]
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 6000
# length of each dataset novices [500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500]

# %% [markdown]
# # Evaluation for first 500 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
    X_test_U2T2 = np.array(df_U2T2['change_column'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (1500,) : [500, 500, 500]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.714468   0.285532  ]
#  [0.05455759 0.94544241]]
# Expert HMM start prob for 2 users:  [5.2041284e-26 1.0000000e+00]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.71448346 0.28551654]
#  [0.05455355 0.94544645]]
# Novice start prob for 2 users:  [1.0888798e-26 1.0000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51403.0990273417
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51574.51078625446
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46747.52530495209
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46891.27241833453
# Participant is an Expert for 2 users:
# ---------------------------------------------------------------------------
# (2000,) : [500, 500, 500, 500]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.94544265 0.05455735]
#  [0.2855311  0.7144689 ]]
# Expert HMM start prob for 3 users:  [1.00000000e+00 5.19952889e-26]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.94544667 0.05455333]
#  [0.2855157  0.7144843 ]]
# Novice start prob for 3 users:  [1.00000000e+00 1.08790668e-26]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51403.09902752652
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.00825227692
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46747.525305056406
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47057.869952175475
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (2500,) : [500, 500, 500, 500, 500]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.94570788 0.05429212]
#  [0.28453611 0.71546389]]
# Expert HMM start prob for 4 users:  [1.00000000e+00 7.11730085e-27]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.94570788 0.05429212]
#  [0.28453611 0.71546389]]
# Novice start prob for 4 users:  [1.00000000e+00 7.11730085e-27]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51399.90296735921
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.00825227692
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.4875684218
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47061.36130105279
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (3000,) : [500, 500, 500, 500, 500, 500]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.94570795 0.05429205]
#  [0.28453582 0.71546418]]
# Expert HMM start prob for 5 users:  [1.00000000e+00 7.11478311e-27]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.94570795 0.05429205]
#  [0.28453582 0.71546418]]
# Novice start prob for 5 users:  [1.00000000e+00 7.11478311e-27]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51574.51078607835
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51574.51078607835
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46888.078927631585
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46891.27241848394
# Participant is an Expert for 5 users:

# %% [markdown]
# # Evaluation for last 500 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
    X_test_U2T2 = np.array(df_U2T2['change_column'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (1500,) : [500, 500, 500]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.8191051  0.1808949 ]
#  [0.20263407 0.79736593]]
# Expert HMM start prob for 2 users:  [0.44326662 0.55673338]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.66705107 0.33294893]
#  [0.20313647 0.79686353]]
# Novice start prob for 2 users:  [0.99020016 0.00979984]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51400.200778416
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51576.13025678126
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.71207534768
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46888.08298945702
# Participant is an Expert for 2 users:
# ---------------------------------------------------------------------------
# (2000,) : [500, 500, 500, 500]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.83397429 0.16602571]
#  [0.13288967 0.86711033]]
# Expert HMM start prob for 3 users:  [0.74512905 0.25487095]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.77018673 0.22981327]
#  [0.2730271  0.7269729 ]]
# Novice start prob for 3 users:  [1.18067493e-10 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.085197809196
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51403.09902727679
# Participant is an Expert for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.569037109984
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47057.8699516541
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (2500,) : [500, 500, 500, 500, 500]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.85448903 0.14551097]
#  [0.14221439 0.85778561]]
# Expert HMM start prob for 4 users:  [0.83451505 0.16548495]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.78981605 0.21018395]
#  [0.26777456 0.73222544]]
# Novice start prob for 4 users:  [0.05626797 0.94373203]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.05538263665
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.64318733464
# Participant is an Expert for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -47058.781194795505
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47059.097163690334
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (3000,) : [500, 500, 500, 500, 500, 500]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.83034446 0.16965554]
#  [0.14451645 0.85548355]]
# Expert HMM start prob for 5 users:  [0.80988357 0.19011643]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.76933341 0.23066659]
#  [0.25598221 0.74401779]]
# Novice start prob for 5 users:  [0.26576465 0.73423535]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51399.98344915434
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.34593642702
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.545828494134
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46888.20477266847
# Participant is an Expert for 5 users:

# %% [markdown]
# # Generate dataset for 600 sequences

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 600 else 600
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:600] if len(data) > 600 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-600:] if len(data) > 600 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)


# creating the dataset of the first 100 sequences task 2 novice users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 600 else 600
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:600] if len(data) > 600 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-600:] if len(data) > 600 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 3600
# length of each dataset experts [600, 600, 600, 600, 600, 600]
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 7200
# length of each dataset novices [600, 600, 600, 600, 600, 600, 600, 600, 600, 600, 600, 600]

# %% [markdown]
# # Evaluation on first 600 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
    X_test_U2T2 = np.array(df_U2T2['change_column'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (1800,) : [600, 600, 600]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.94196772 0.05803228]
#  [0.25661162 0.74338838]]
# Expert HMM start prob for 2 users:  [1.00000000e+00 1.19310585e-30]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.94181238 0.05818762]
#  [0.25704585 0.74295415]]
# Novice start prob for 2 users:  [1.00000000e+00 3.25103347e-28]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.00825227692
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.00825227692
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.4875684218
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46891.27241848394
# Participant is an Expert for 2 users:
# ---------------------------------------------------------------------------
# (2400,) : [600, 600, 600, 600]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.94207035 0.05792965]
#  [0.25632557 0.74367443]]
# Expert HMM start prob for 3 users:  [1.00000000e+00 4.94369401e-30]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.94207035 0.05792965]
#  [0.25632557 0.74367443]]
# Novice start prob for 3 users:  [1.00000000e+00 4.94369401e-30]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51574.51078607835
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51403.09902752652
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.4875684218
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46744.4875684218
# Participant is a Novice for 3 users:
# ---------------------------------------------------------------------------
# (3000,) : [600, 600, 600, 600, 600]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.94224453 0.05775547]
#  [0.25583877 0.74416123]]
# Expert HMM start prob for 4 users:  [1.00000000e+00 1.88705691e-31]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.94236597 0.05763403]
#  [0.25549962 0.74450038]]
# Novice start prob for 4 users:  [1.00000000e+00 8.19945059e-30]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.00825227692
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51574.51078607835
# Participant is an Expert for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46891.27241848394
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46744.4875684218
# Participant is a Novice for 4 users:
# ---------------------------------------------------------------------------
# (3600,) : [600, 600, 600, 600, 600, 600]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.94236604 0.05763396]
#  [0.25549942 0.74450058]]
# Expert HMM start prob for 5 users:  [1.00000000e+00 8.19789154e-30]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.94232824 0.05767176]
#  [0.25560468 0.74439532]]
# Novice start prob for 5 users:  [1.00000000e+00 7.85155477e-31]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51403.09902752652
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51403.09902752652
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46891.27241848394
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47061.36130105279
# Participant is an Expert for 5 users:

# %% [markdown]
# # Evaluation on last 600 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
    X_test_U2T2 = np.array(df_U2T2['change_column'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (1800,) : [600, 600, 600]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.75743712 0.24256288]
#  [0.19407227 0.80592773]]
# Expert HMM start prob for 2 users:  [2.27901794e-13 1.00000000e+00]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.7955629  0.2044371 ]
#  [0.31320541 0.68679459]]
# Novice start prob for 2 users:  [0.05031308 0.94968692]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51253.04369471767
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51399.92277068735
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46747.525305223884
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46745.170231461576
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (2400,) : [600, 600, 600, 600]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.80417394 0.19582606]
#  [0.14429759 0.85570241]]
# Expert HMM start prob for 3 users:  [0.36368612 0.63631388]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.7862749  0.2137251 ]
#  [0.21101954 0.78898046]]
# Novice start prob for 3 users:  [0.38361452 0.61638548]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51400.07331932085
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51400.24869075615
# Participant is an Expert for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -47058.46294635753
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47058.43722019848
# Participant is a Novice for 3 users:
# ---------------------------------------------------------------------------
# (3000,) : [600, 600, 600, 600, 600]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.83277824 0.16722176]
#  [0.14719021 0.85280979]]
# Expert HMM start prob for 4 users:  [0.42855242 0.57144758]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.79615707 0.20384293]
#  [0.23623174 0.76376826]]
# Novice start prob for 4 users:  [0.20844115 0.79155885]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51400.212136262584
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51574.65309348836
# Participant is an Expert for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.72111337562
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47058.0264525995
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (3600,) : [600, 600, 600, 600, 600, 600]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.85704376 0.14295624]
#  [0.19348833 0.80651167]]
# Expert HMM start prob for 5 users:  [0.70820365 0.29179635]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.7826915  0.2173085 ]
#  [0.24211095 0.75788905]]
# Novice start prob for 5 users:  [0.08498881 0.91501119]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.324049388524
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51400.64006216468
# Participant is an Expert for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.8202073851
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46745.08101020681
# Participant is an Expert for 5 users:

# %% [markdown]
# # Generate dataset for 700 sequences

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 700 else 700
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:700] if len(data) > 700 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-700:] if len(data) > 700 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)


# creating the dataset of the first 100 sequences task 2 novice users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 700 else 700
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:700] if len(data) > 700 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-700:] if len(data) > 700 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 4200
# length of each dataset experts [700, 700, 700, 700, 700, 700]
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 8400
# length of each dataset novices [700, 700, 700, 700, 700, 700, 700, 700, 700, 700, 700, 700]

# %% [markdown]
# # Evaluation for first 700 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
    X_test_U2T2 = np.array(df_U2T2['change_column'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (2100,) : [700, 700, 700]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.93803272 0.06196728]
#  [0.2648727  0.7351273 ]]
# Expert HMM start prob for 2 users:  [1.00000000e+00 3.30580867e-27]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.9379324  0.0620676 ]
#  [0.26514982 0.73485018]]
# Novice start prob for 2 users:  [1.00000000e+00 2.27632894e-26]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51253.04369507151
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.00825227692
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.4875684218
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46747.525305056406
# Participant is an Expert for 2 users:
# ---------------------------------------------------------------------------
# (2800,) : [700, 700, 700, 700]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.73590748 0.26409252]
#  [0.06168371 0.93831629]]
# Expert HMM start prob for 3 users:  [5.22039429e-28 1.00000000e+00]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.93823319 0.06176681]
#  [0.26432224 0.73567776]]
# Novice start prob for 3 users:  [1.00000000e+00 3.59480439e-27]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51253.04369458986
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51577.95146189383
# Participant is an Expert for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.48756857226
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47061.36130105279
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (3500,) : [700, 700, 700, 700, 700]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.93855109 0.06144891]
#  [0.2634455  0.7365545 ]]
# Expert HMM start prob for 4 users:  [1.00000000e+00 8.24495552e-29]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.7365545  0.2634455 ]
#  [0.06144891 0.93855109]]
# Novice start prob for 4 users:  [8.24495552e-29 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51574.51078607835
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.00825226868
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -47061.36130105279
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47057.869952009794
# Participant is a Novice for 4 users:
# ---------------------------------------------------------------------------
# (4200,) : [700, 700, 700, 700, 700, 700]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.73636433 0.26363567]
#  [0.06151767 0.93848233]]
# Expert HMM start prob for 5 users:  [5.67645819e-28 1.00000000e+00]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.73636433 0.26363567]
#  [0.06151767 0.93848233]]
# Novice start prob for 5 users:  [5.67645819e-28 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51399.902966611895
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51403.0990273417
# Participant is an Expert for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46888.07892739243
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46888.07892739243
# Participant is a Novice for 5 users:

# %% [markdown]
# # Evaluation for last 700 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
    X_test_U2T2 = np.array(df_U2T2['change_column'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (2100,) : [700, 700, 700]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.76387137 0.23612863]
#  [0.20157077 0.79842923]]
# Expert HMM start prob for 2 users:  [1.00000000e+00 3.60196076e-25]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.80928267 0.19071733]
#  [0.2837216  0.7162784 ]]
# Novice start prob for 2 users:  [0.85176277 0.14823723]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51577.95146189383
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51574.60946113188
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46891.27241848394
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46888.14477155374
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (2800,) : [700, 700, 700, 700]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.84863253 0.15136747]
#  [0.20058422 0.79941578]]
# Expert HMM start prob for 3 users:  [0.18382234 0.81617766]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.80298463 0.19701537]
#  [0.1800205  0.8199795 ]]
# Novice start prob for 3 users:  [0.73352274 0.26647726]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51400.4626172546
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51400.360886054295
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46888.67341265755
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47058.075045681086
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (3500,) : [700, 700, 700, 700, 700]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.84683766 0.15316234]
#  [0.17158911 0.82841089]]
# Expert HMM start prob for 4 users:  [0.22816644 0.77183356]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.78744165 0.21255835]
#  [0.19159852 0.80840148]]
# Novice start prob for 4 users:  [0.55985148 0.44014852]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51400.40491170371
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.16046065922
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -47058.04269174508
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47058.237309228374
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (4200,) : [700, 700, 700, 700, 700, 700]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.85232088 0.14767912]
#  [0.20061508 0.79938492]]
# Expert HMM start prob for 5 users:  [0.35446299 0.64553701]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.79525424 0.20474576]
#  [0.22259139 0.77740861]]
# Novice start prob for 5 users:  [0.24838269 0.75161731]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.27704150586
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.36148431221
# Participant is an Expert for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46888.47484390916
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47058.63039522992
# Participant is an Expert for 5 users:

# %% [markdown]
# # Generate dataset for 800 sequences

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 800 else 800
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:800] if len(data) > 800 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-800:] if len(data) > 800 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)


# creating the dataset of the first 100 sequences task 2 novice users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 800 else 800
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:800] if len(data) > 800 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-800:] if len(data) > 800 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 4800
# length of each dataset experts [800, 800, 800, 800, 800, 800]
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 9600
# length of each dataset novices [800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800]

# %% [markdown]
# # Evaluation for first 800 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
    X_test_U2T2 = np.array(df_U2T2['change_column'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (2400,) : [800, 800, 800]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.92722531 0.07277469]
#  [0.28692664 0.71307336]]
# Expert HMM start prob for 2 users:  [1.00000000e+00 4.97662717e-28]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.92722531 0.07277469]
#  [0.28692664 0.71307336]]
# Novice start prob for 2 users:  [1.00000000e+00 4.97662717e-28]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51574.51078607835
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51399.90296735921
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.4875684218
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46888.078927631585
# Participant is an Expert for 2 users:
# ---------------------------------------------------------------------------
# (3200,) : [800, 800, 800, 800]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.92754663 0.07245337]
#  [0.28613358 0.71386642]]
# Expert HMM start prob for 3 users:  [1.00000000e+00 8.26145379e-29]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.7143307  0.2856693 ]
#  [0.07226683 0.92773317]]
# Novice start prob for 3 users:  [7.28260253e-30 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.00825227692
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51574.51078625446
# Participant is an Expert for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.4875684218
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46744.48756857226
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (4000,) : [800, 800, 800, 800, 800]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.7145451  0.2854549 ]
#  [0.07217823 0.92782177]]
# Expert HMM start prob for 4 users:  [1.37092501e-29 1.00000000e+00]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.92782177 0.07217823]
#  [0.2854549  0.7145451 ]]
# Novice start prob for 4 users:  [1.00000000e+00 1.37092501e-29]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51577.951461414756
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.00825227692
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46891.27241833453
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47061.36130105279
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (4800,) : [800, 800, 800, 800, 800, 800]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.71494189 0.28505811]
#  [0.07201851 0.92798149]]
# Expert HMM start prob for 5 users:  [1.20803742e-30 1.00000000e+00]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.71494189 0.28505811]
#  [0.07201851 0.92798149]]
# Novice start prob for 5 users:  [1.20803742e-30 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51253.04369458986
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51403.0990273417
# Participant is an Expert for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46891.27241833453
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47061.36130073741
# Participant is an Expert for 5 users:

# %% [markdown]
# # Evaluation for last 800 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
    X_test_U2T2 = np.array(df_U2T2['change_column'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (2400,) : [800, 800, 800]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.80431551 0.19568449]
#  [0.20704817 0.79295183]]
# Expert HMM start prob for 2 users:  [0.48326868 0.51673132]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.81658819 0.18341181]
#  [0.29671117 0.70328883]]
# Novice start prob for 2 users:  [0.39000648 0.60999352]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.18136938307
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51400.24330857636
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.68874442181
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46888.27781810501
# Participant is an Expert for 2 users:
# ---------------------------------------------------------------------------
# (3200,) : [800, 800, 800, 800]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.85476205 0.14523795]
#  [0.18537043 0.81462957]]
# Expert HMM start prob for 3 users:  [6.37250646e-04 9.99362749e-01]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.80049981 0.19950019]
#  [0.19637073 0.80362927]]
# Novice start prob for 3 users:  [0.25464304 0.74535696]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51251.85566877651
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51400.374000598655
# Participant is an Expert for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.487742994635
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46888.58032750483
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (4000,) : [800, 800, 800, 800, 800]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.84176863 0.15823137]
#  [0.15101625 0.84898375]]
# Expert HMM start prob for 4 users:  [9.99999963e-01 3.69932028e-08]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.7908694  0.2091306 ]
#  [0.18984698 0.81015302]]
# Novice start prob for 4 users:  [0.47957873 0.52042127]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51403.09904835193
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51400.17390345398
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -47057.869952023306
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46744.69082471662
# Participant is a Novice for 4 users:
# ---------------------------------------------------------------------------
# (4800,) : [800, 800, 800, 800, 800, 800]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.81670442 0.18329558]
#  [0.14656468 0.85343532]]
# Expert HMM start prob for 5 users:  [0.80495528 0.19504472]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.78507326 0.21492674]
#  [0.20628329 0.79371671]]
# Novice start prob for 5 users:  [0.66284956 0.33715044]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51399.985758016766
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.1160632904
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -47058.723160908376
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46888.24536916055
# Participant is a Novice for 5 users:

# %% [markdown]
# # Generate dataset for 900 sequences

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 900 else 900
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:900] if len(data) > 900 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-900:] if len(data) > 900 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)


# creating the dataset of the first 100 sequences task 2 novice users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 900 else 900
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:900] if len(data) > 900 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-900:] if len(data) > 900 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 5400
# length of each dataset experts [900, 900, 900, 900, 900, 900]
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 10800
# length of each dataset novices [900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900, 900]

# %% [markdown]
# # Evaluation for first 900 sequence

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
    X_test_U2T2 = np.array(df_U2T2['change_column'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (2700,) : [900, 900, 900]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.92443772 0.07556228]
#  [0.31338606 0.68661394]]
# Expert HMM start prob for 2 users:  [1.00000000e+00 4.48159049e-26]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.92443772 0.07556228]
#  [0.31338606 0.68661394]]
# Novice start prob for 2 users:  [1.00000000e+00 4.48159049e-26]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51577.95146189383
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.00825227692
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46888.078927631585
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46891.27241848394
# Participant is an Expert for 2 users:
# ---------------------------------------------------------------------------
# (3600,) : [900, 900, 900, 900]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.68735981 0.31264019]
#  [0.07530668 0.92469332]]
# Expert HMM start prob for 3 users:  [3.32515649e-27 1.00000000e+00]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.68735981 0.31264019]
#  [0.07530668 0.92469332]]
# Novice start prob for 3 users:  [3.32515649e-27 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51574.51078625446
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51574.51078625446
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46891.27241833453
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47061.36130073741
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (4500,) : [900, 900, 900, 900, 900]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.92493681 0.07506319]
#  [0.31193467 0.68806533]]
# Expert HMM start prob for 4 users:  [1.00000000e+00 5.49120934e-28]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.92496048 0.07503952]
#  [0.311869   0.688131  ]]
# Novice start prob for 4 users:  [1.00000000e+00 1.22280541e-27]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51574.51078607835
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51403.09902752652
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -47057.869952175475
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47061.36130105279
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (5400,) : [900, 900, 900, 900, 900, 900]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.68813109 0.31186891]
#  [0.0750395  0.9249605 ]]
# Expert HMM start prob for 5 users:  [1.22266575e-27 1.00000000e+00]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.9249605  0.0750395 ]
#  [0.31186891 0.68813109]]
# Novice start prob for 5 users:  [1.00000000e+00 1.22266575e-27]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51403.0990273417
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51399.90296735921
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.48756857226
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46888.078927631585
# Participant is an Expert for 5 users:

# %% [markdown]
# # Evaluation for last 900 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
    X_test_U2T2 = np.array(df_U2T2['change_column'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (2700,) : [900, 900, 900]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.81005873 0.18994127]
#  [0.1943006  0.8056994 ]]
# Expert HMM start prob for 2 users:  [0.55940571 0.44059429]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.82978171 0.17021829]
#  [0.29328526 0.70671474]]
# Novice start prob for 2 users:  [1.00000000e+00 2.08150579e-12]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.16066887735
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51253.04369455315
# Participant is an Expert for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -47058.23776346005
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46888.07892769337
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (3600,) : [900, 900, 900, 900]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.81245552 0.18754448]
#  [0.14814937 0.85185063]]
# Expert HMM start prob for 3 users:  [0.67390731 0.32609269]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.81255017 0.18744983]
#  [0.19828335 0.80171665]]
# Novice start prob for 3 users:  [9.99999947e-01 5.27157816e-08]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51574.745446833374
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51574.51078605737
# Participant is an Novice for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46888.50252619479
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47061.36131277547
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (4500,) : [900, 900, 900, 900, 900]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.84339373 0.15660627]
#  [0.16591691 0.83408309]]
# Expert HMM start prob for 4 users:  [0.31040797 0.68959203]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.78142309 0.21857691]
#  [0.18411599 0.81588401]]
# Novice start prob for 4 users:  [0.00122875 0.99877125]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.30931382438
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51577.26367367982
# Participant is an Expert for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46888.51854187643
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46890.181568947846
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (5400,) : [900, 900, 900, 900, 900, 900]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.85198787 0.14801213]
#  [0.1884435  0.8115565 ]]
# Expert HMM start prob for 5 users:  [0.54422275 0.45577725]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.80434339 0.19565661]
#  [0.22934635 0.77065365]]
# Novice start prob for 5 users:  [9.99977727e-01 2.22730341e-05]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51400.19133873837
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51253.06845803037
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.65626711225
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47061.36621578848
# Participant is an Expert for 5 users:

# %% [markdown]
# # Generate dataset for 1000 sequences

# %%
# creating the dataset of the first 100 sequences task 2 expert users

X_train_experts_task2 = datasets_experts_task2[0]
print(np.asarray(X_train_experts_task2).shape, ":", len_datasets_experts_task2[0])

X_train_experts_task2_first100 = []
len_datasets_experts_task2_first_last_100 = []

X_train_experts_task2_last100 = []


X_train_experts_task2_mid100 = []
len_datasets_experts_task2_mid100 = []

for x in len_datasets_experts_task2[0]:
    print("lengths: ", x)
    data = X_train_experts_task2[:x]
    length_of_each_dataset_first_100 = x if x < 1000 else 1000
    len_datasets_experts_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:1000] if len(data) > 1000 else data
    X_train_experts_task2_first100 = np.concatenate([X_train_experts_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-1000:] if len(data) > 1000 else data
    X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_experts_task2_first100:", len(X_train_experts_task2_first100))
print("length of each dataset experts", len_datasets_experts_task2_first_last_100)


# creating the dataset of the first 100 sequences task 2 novice users

X_train_novices_task2 = datasets_novices_task2[0]
print(np.asarray(X_train_novices_task2).shape, ":", len_datasets_novices_task2[0])

X_train_novices_task2_first100 = []
len_datasets_novices_task2_first_last_100 = []

X_train_novices_task2_last100 = []


X_train_novices_task2_mid100 = []
len_datasets_novices_task2_mid100 = []

for x in len_datasets_novices_task2[0]:
    print("lengths: ", x)
    data = X_train_novices_task2[:x]
    length_of_each_dataset_first_100 = x if x < 1000 else 1000
    len_datasets_novices_task2_first_last_100.append(length_of_each_dataset_first_100)
    final_data_first100 = data[:1000] if len(data) > 1000 else data
    X_train_novices_task2_first100 = np.concatenate([X_train_novices_task2_first100,final_data_first100])
  
    # create dataset for the last 100
    final_data_last_100 = data[x-1000:] if len(data) > 1000 else data
    X_train_novices_task2_last100 = np.concatenate([X_train_novices_task2_last100,final_data_last_100])
    
    #create dataset for the mid 100
#     length_of_each_dataset_last_100 = x if x < 100 else 100
#     final_data_last_100 = data[x-100:] if len(data) > 100 else data
#     X_train_experts_task2_last100 = np.concatenate([X_train_experts_task2_last100,final_data_last_100])

print("X_train_novices_task2_first100:", len(X_train_novices_task2_first100))
print("length of each dataset novices", len_datasets_novices_task2_first_last_100)
# Out:
# (471956,) : [78280, 75609, 81123, 74668, 82666, 79610]
# lengths:  78280
# lengths:  75609
# lengths:  81123
# lengths:  74668
# lengths:  82666
# lengths:  79610
# X_train_experts_task2_first100: 6000
# length of each dataset experts [1000, 1000, 1000, 1000, 1000, 1000]
# (778352,) : [60102, 57584, 66855, 65112, 62252, 70262, 62322, 69513, 69124, 63768, 69513, 61945]
# lengths:  60102
# lengths:  57584
# lengths:  66855
# lengths:  65112
# lengths:  62252
# lengths:  70262
# lengths:  62322
# lengths:  69513
# lengths:  69124
# lengths:  63768
# lengths:  69513
# lengths:  61945
# X_train_novices_task2_first100: 12000
# length of each dataset novices [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]

# %% [markdown]
# # Evaluation for first 1000 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_first100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_first100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
    X_test_U2T2 = np.array(df_U2T2['change_column'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (3000,) : [1000, 1000, 1000]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.69213359 0.30786641]
#  [0.09076183 0.90923817]]
# Expert HMM start prob for 2 users:  [1.45917004e-27 1.00000000e+00]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.90929304 0.09070696]
#  [0.30773762 0.69226238]]
# Novice start prob for 2 users:  [1.00000000e+00 3.36211913e-27]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51403.0990273417
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51399.90296735921
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46891.27241833453
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46744.4875684218
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (4000,) : [1000, 1000, 1000, 1000]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.69293736 0.30706264]
#  [0.09043637 0.90956363]]
# Expert HMM start prob for 3 users:  [2.48204282e-28 1.00000000e+00]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.69304842 0.30695158]
#  [0.09038946 0.90961054]]
# Novice start prob for 3 users:  [5.71789926e-28 1.00000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51250.00825226868
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51577.951461414756
# Participant is an Expert for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46747.52530495209
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46891.27241833453
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (5000,) : [1000, 1000, 1000, 1000, 1000]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.90988211 0.09011789]
#  [0.30627845 0.69372155]]
# Expert HMM start prob for 4 users:  [1.0000000e+00 9.7176661e-29]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.69372155 0.30627845]
#  [0.09011789 0.90988211]]
# Novice start prob for 4 users:  [9.7176661e-29 1.0000000e+00]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51577.95146189383
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51403.0990273417
# Participant is an Novice for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -47061.36130105279
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46888.07892739243
# Participant is a Novice for 4 users:
# ---------------------------------------------------------------------------
# (6000,) : [1000, 1000, 1000, 1000, 1000, 1000]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.91011428 0.08988572]
#  [0.30570242 0.69429758]]
# Expert HMM start prob for 5 users:  [1.00000000e+00 1.65051853e-29]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.91011428 0.08988572]
#  [0.30570242 0.69429758]]
# Novice start prob for 5 users:  [1.00000000e+00 1.65051853e-29]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51399.90296735921
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51577.95146189383
# Participant is an Expert for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46891.27241848394
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46744.4875684218
# Participant is a Novice for 5 users:

# %% [markdown]
# # Evaluation or last 1000 sequences

# %%
# Train a HMM for the Experts in Task 2

for i in range(2,6):
    
    
    print('---------------------------------------------------------------------------')
    
    states = ["Expert", "Novice"]
    n_states = len(states)
    
    leng_expert = len_datasets_experts_task2_first_last_100[0:i+1]
    
    X_train_experts_task2 = X_train_experts_task2_last100[0: np.sum(leng_expert)]

    print(np.asarray(X_train_experts_task2).shape, ":", leng_expert)

    # Learning model parameters: transmission & emission matrices

    model_train_experts_task2= hmm.GaussianHMM(n_components=n_states, covariance_type="full", n_iter=1000)
    model_train_experts_task2.fit(X_train_experts_task2.reshape(-1,1), leng_expert)


    print("Expert HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_experts_task2.transmat_)

    print("Expert HMM start prob for %s users: " %(i), model_train_experts_task2.startprob_)
    
    
    leng_novice = len_datasets_novices_task2_first_last_100[0:i+1]
    
    X_train_novices_task2 = X_train_novices_task2_last100[0: np.sum(leng_expert)]

    # Learning model parameters: transmission & emission matrices


    model_train_novices_task2= hmm.GaussianHMM(n_components=n_states,covariance_type="full", n_iter=1000)
    model_train_novices_task2.fit(X_train_novices_task2.reshape(-1,1), leng_novice)


    print("Novice HMM: Transition Probabilities for %s users: " %(i))
    print(model_train_novices_task2.transmat_)
    print("Novice start prob for %s users: " %(i), model_train_novices_task2.startprob_)
    
    
    
    print('----------------Model Evaluation for EXPERT user---------------------')
    
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Expert User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")

    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U3T2_new= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Experts/U3T2_new.csv')
    X_test_U3T2_new = np.array((df_U3T2_new['change_column']))
    print("X_test_U3T2_new : ", X_test_U3T2_new.shape)

    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_expert = model_test_expert.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U3T2_new.reshape(-1, 1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_novice = model_test_novice.decode(X_test_U3T2_new.reshape(-1, 1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is an Novice for %s users: " %(i))
        
    
    print("\n--------------------------------- Model Evaluation for NOVICE user -----------------------------------")
      
    print("\n--------------------------------- Model: Expert -----------------------------------")
    print("Testing with Novice User")
    model_test_expert = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_expert.startprob_ = model_train_experts_task2.startprob_

    model_test_expert.transprob_ = np.array([
      [model_train_experts_task2.transmat_[0, 0], model_train_experts_task2.transmat_[0, 1]],
      [model_train_experts_task2.transmat_[1, 0], model_train_experts_task2.transmat_[1, 1]]
    ])



    df_U2T2= pd.read_csv(CONSTANTS.path_to_csv_per_user_correctness_test+'/Task2/Novices/U2T2_new.csv')
    X_test_U2T2 = np.array(df_U2T2['change_column'])
    # Estimate model parameters.
    model_test_expert = model_test_expert.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_expert_task2, predicted_hidden_states_rainy = model_test_expert.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Expert at Task 2:")
    print(logprob_expert_task2)


    print("\n--------------------------------- Model: Novice -----------------------------------")



    model_test_novice = hmm.GaussianHMM(n_components=n_states, init_params="")


    # Rainy
    model_test_novice.startprob_ = model_train_novices_task2.startprob_

    model_test_novice.transprob_ = np.array([
      [model_train_novices_task2.transmat_[0, 0], model_train_novices_task2.transmat_[0, 1]],
      [model_train_novices_task2.transmat_[1, 0], model_train_novices_task2.transmat_[1, 1]]
    ])




    # Estimate model parameters.
    model_test_novice = model_test_novice.fit(X_test_U2T2.reshape(-1,1))


    # Find most likely state (hidden) sequence corresponding to the observation sequence
    # We use the following function "decode": the first argument should be the observation sequence (matrix)
    logprob_novice_task2, predicted_hidden_states_rainy = model_test_novice.decode(X_test_U2T2.reshape(-1,1), algorithm="viterbi")




    print("\nProbability of Novice at Task 2:")
    print(logprob_novice_task2)


    if logprob_expert_task2 > logprob_novice_task2:
        print("Participant is an Expert for %s users: " %(i))

    else:
        print("Participant is a Novice for %s users: " %(i))
# Out:
# ---------------------------------------------------------------------------
# (3000,) : [1000, 1000, 1000]
# Expert HMM: Transition Probabilities for 2 users:
# [[0.81839375 0.18160625]
#  [0.1848929  0.8151071 ]]
# Expert HMM start prob for 2 users:  [1.57049593e-17 1.00000000e+00]
# Novice HMM: Transition Probabilities for 2 users:
# [[0.83688043 0.16311957]
#  [0.29441328 0.70558672]]
# Novice start prob for 2 users:  [0.3160531 0.6839469]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51253.04369458986
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.10779920567
# Participant is an Novice for 2 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -47057.869952009794
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46888.51271567052
# Participant is a Novice for 2 users:
# ---------------------------------------------------------------------------
# (4000,) : [1000, 1000, 1000, 1000]
# Expert HMM: Transition Probabilities for 3 users:
# [[0.85305599 0.14694401]
#  [0.18415776 0.81584224]]
# Expert HMM start prob for 3 users:  [1.00000000e+00 3.18526603e-16]
# Novice HMM: Transition Probabilities for 3 users:
# [[0.82088991 0.17911009]
#  [0.19589091 0.80410909]]
# Novice start prob for 3 users:  [0.14480485 0.85519515]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51253.04369484666
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51575.39033961788
# Participant is an Expert for 3 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.4875684218
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46744.978908648285
# Participant is an Expert for 3 users:
# ---------------------------------------------------------------------------
# (5000,) : [1000, 1000, 1000, 1000, 1000]
# Expert HMM: Transition Probabilities for 4 users:
# [[0.8420952 0.1579048]
#  [0.1662896 0.8337104]]
# Expert HMM start prob for 4 users:  [0.73075183 0.26924817]
# Novice HMM: Transition Probabilities for 4 users:
# [[0.82257875 0.17742125]
#  [0.22172904 0.77827096]]
# Novice start prob for 4 users:  [0.43246334 0.56753666]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51400.0221275098
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51400.20908932426
# Participant is an Expert for 4 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -46744.574467280174
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -47058.37722013736
# Participant is an Expert for 4 users:
# ---------------------------------------------------------------------------
# (6000,) : [1000, 1000, 1000, 1000, 1000, 1000]
# Expert HMM: Transition Probabilities for 5 users:
# [[0.84909439 0.15090561]
#  [0.18484275 0.81515725]]
# Expert HMM start prob for 5 users:  [0.813439 0.186561]
# Novice HMM: Transition Probabilities for 5 users:
# [[0.77049366 0.22950634]
#  [0.18854996 0.81145004]]
# Novice start prob for 5 users:  [0.37965151 0.62034849]
# ----------------Model Evaluation for EXPERT user---------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Expert User
# X_test_U3T2_new :  (14160,)
#
# Probability of Expert at Task 2:
# -51575.30958765185
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -51250.2600244677
# Participant is an Novice for 5 users:
#
# --------------------------------- Model Evaluation for NOVICE user -----------------------------------
#
# --------------------------------- Model: Expert -----------------------------------
# Testing with Novice User
#
# Probability of Expert at Task 2:
# -47058.00875632076
#
# --------------------------------- Model: Novice -----------------------------------
#
# Probability of Novice at Task 2:
# -46888.451520945004
# Participant is a Novice for 5 users:
