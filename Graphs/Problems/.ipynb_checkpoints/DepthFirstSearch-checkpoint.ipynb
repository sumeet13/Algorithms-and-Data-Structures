# %%
import sys
NINF = float('-inf')


def initialize():

    for i in range(V):
        for j in range(V):

            dist[i][j] = graph[i][j]

            if dist[i][j] == NINF:
                next_[i][j] = -1

            else:
                next_[i][j] = j


def dfs(u, path, time):
        
        counter = 0
        
        
        for i in range(V):
            
            if graph[u][i] not in (NINF,0):
                dfs(i, path+[i], time + graph[u][i])
            else:
                counter +=1
                
        if counter==V:
            print('paths')
            all_paths.append((time,path))
            
        

    


# A utility function to print the solution
def printSolution():
    print(
        "\nFollowing matrix shows the shortest distances between every pair of vertices"
    )

    for i in range(V):
        print(dist[i])

    print("\nFollowing matrix shows the path matrix")
    for i in range(V):
        print(next_[i])


def constructPath(u, v):
    path = []

    print("\nThe path between from %d -> %d is: " % (u, v))
    if next_[u][v] == -1:
        print("No path exists")
        return
    path.append(u)
    sum_path = 0
    while (u != v):
        next_u = next_[u][v]
        sum_path += graph[u][next_u]
        u = next_u
        path.append(u)

    print(sum_path,path)


def findCriticalPath():
    u, v = -1, -1
    max_timing = NINF
    for i in range(V):
        for j in range(V):

            if max_timing < dist[i][j]:

                max_timing = dist[i][j]
                u, v = i, j
    return u, v


# Driver program to test the above program
# Let us create the following weighted graph
""" 
            10 
       (0)<-------(3) 
        |         /|\ 
      5 |          | 
        |          | 1 
       \|/         | 
       (1)------->(2) 
            3           """
# graph = [[0, 5, INF, INF], 
#         [INF, 0, 3, INF], 
#         [INF, INF, 0, 1],
#         [5, INF, INF, 0]]

# graph = [[0   , 5    , NINF, NINF, NINF, NINF, NINF, NINF, NINF, NINF], 
#          [NINF, 0    , 1   , NINF, NINF, 4   , NINF, NINF, NINF, NINF], 
#          [NINF, NINF , 0   , 2   , NINF, 2   , NINF, NINF, NINF, NINF],
#          [NINF, NINF , NINF, 0   , NINF, NINF, NINF, NINF, NINF, NINF],
#          [NINF, 3    , NINF, NINF, 0   , 9   , NINF, NINF, NINF, NINF],
#          [NINF, NINF , NINF, NINF, NINF, 0   , 5   , NINF, 5   , NINF], 
#          [NINF, NINF , NINF, NINF, NINF, NINF, 0   , NINF, NINF, NINF], 
#          [NINF, NINF , NINF, NINF, NINF, NINF, NINF, 0   , 6   , NINF],
#          [NINF, NINF , NINF, NINF, NINF, NINF, NINF, NINF, 0   , 11  ],
#          [NINF, NINF , NINF, NINF, NINF, NINF, NINF, NINF, NINF, 0   ],
#          ]

graph =[[0,NINF,NINF,1,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,0,5,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,0,NINF,NINF,NINF,NINF,NINF,3,2,1,NINF,NINF,NINF],
[NINF,NINF,NINF,0,2,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,0,3,5,3,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,4,5,6,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,3,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,2,3,6,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,8,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,9,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,7],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0]]
# Print the solution
V = len(graph)

dist = [[0 for j in range(V)] for _ in range(V)]

next_ = [[-1 for j in range(V)] for _ in range(V)]

visited = ['U' for i in range(V)]
all_paths = []

sources = [0,1]
for s in sources:
    dfs(s,[s],0)
print(all_paths)

# u, v = findCriticalPath()

# print(dist[u][v])
# constructPath(0, 11)
# Out:
# paths
# paths
# paths
# paths
# paths
# paths
# paths
# paths
# paths
# paths
# [(18, [0, 3, 4, 5, 8, 11]), (20, [0, 3, 4, 5, 9, 12]), (19, [0, 3, 4, 5, 10, 13]), (19, [0, 3, 4, 6, 8, 11]), (16, [0, 3, 4, 7, 8, 11]), (18, [0, 3, 4, 7, 9, 12]), (19, [0, 3, 4, 7, 10, 13]), (16, [1, 2, 8, 11]), (16, [1, 2, 9, 12]), (13, [1, 2, 10, 13])]

# %%
[[0,5,1,2,6,1,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,0,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,2,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,0,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,1,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,0,NINF,NINF,NINF,NINF,NINF,NINF,NINF,2,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,0,NINF,NINF,NINF,NINF,NINF,NINF,1,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,NINF,NINF,NINF,1,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,0,2,3,3,2,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,5,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,NINF,NINF,NINF,NINF,NINF,6,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,NINF,NINF,NINF,NINF,NINF,9,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,NINF,NINF,NINF,NINF,10,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,1,2,3,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,5,1,3,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,1,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,3,2,4,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,5,6,7,1,2,5,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,NINF,NINF,NINF,NINF,NINF,8,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,NINF,NINF,NINF,NINF,NINF,9],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0]]
# Out:
# [[0,
#   5,
#   1,
#   2,
#   6,
#   1,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf],
#  [-inf,
#   0,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   2,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf],
#  [-inf,
#   -inf,
#   0,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   1,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf],
#  [-inf,
#   -inf,
#   -inf,
#   0,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   2,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
#   -inf,
# ...

# %%
[[0,NINF,NINF,1,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,0,5,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,0,NINF,NINF,NINF,NINF,NINF,3,2,1,NINF,NINF,NINF],
[NINF,NINF,NINF,0,2,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,0,3,5,3,NINF,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,4,5,6,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,3,NINF,NINF,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,2,3,6,NINF,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,8,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,7,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF,7],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0,NINF],
[NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,NINF,0]]
